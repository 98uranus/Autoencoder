# %%
from sklearn.mixture import GaussianMixture
from sklearn.metrics import precision_score, recall_score, f1_score, auc
from sklearn.model_selection import train_test_split
from keras import layers, Model
from keras.models import Sequential, load_model
import numpy as np
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping
from keras import regularizers, layers, losses
from keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn.metrics import precision_recall_curve, confusion_matrix, roc_curve, PrecisionRecallDisplay
from keras.utils import plot_model
import pandas as pd
import seaborn as sns
import joblib

# %%
# Generate some sample data for the autoencoder
# x_train = np.random.rand(1000, 12)
# x_test = np.random.rand(100, 12)

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

RANDOM_SEED = 42

df = pd.read_csv("Autoencoder_wind.csv")  
print(df.shape)

LABELS = ["Normal", "Abnormal"]

count_classes =pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Data Class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Data")
plt.show();

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from cmath import pi

data = df.drop(['Time'], axis=1)
y_true = df['Class']

r2d = 180/pi

data['P'] = r2d * data['P']
data['Q'] = r2d * data['Q']
data['R'] = r2d * data['R']
data['Phi'] = r2d * data['Phi']
data['Theta'] = r2d * data['Theta']
data['Psi'] = r2d * data['Psi']
# Out:
# (40000, 14)

# %%
X_train, X_test = train_test_split(data, test_size=0.5, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
y_train = X_train['Class']
X_train = pd.DataFrame(X_train)
X_train = X_train.drop(['Class'], axis=1)

# X_test = X_test[X_test.Class == 0]
y_test = X_test['Class']
X_test = pd.DataFrame(X_test)
X_test = X_test.drop(['Class'], axis=1)

# def normalize(label):
#     str = StandardScaler()
#     str.fit(X_train[label].values.reshape(-1, 1))
#     X_train[label] = str.transform(X_train[label].values.reshape(-1, 1))
#     X_test[label] = str.transform(X_test[label].values.reshape(-1, 1))

# def normalize1(label):
#     str = MinMaxScaler()
#     str.fit(X_train[label].values.reshape(-1, 1))
#     X_train[label] = str.transform(X_train[label].values.reshape(-1, 1))
#     X_test[label] = str.transform(X_test[label].values.reshape(-1, 1))

# A = ['RPM1', 'RPM2', 'RPM3', 'RPM4', 'RPM5', 'RPM6', 'P', 'Q', 'R', 'Phi', 'Theta', 'Psi']

# for i in A:
#     normalize(i)

def MinmaxNorm(data1, data2, label):
    for i in label:
        a = data1[i]
        b = data2[i]
        x_max = max(a)
        x_min = min(a)
        for j in list(range(a.shape[0])):
            a.iloc[j] = (a.iloc[j] - x_min) / (x_max - x_min)
        for k in list(range(b.shape[0])):
            b.iloc[k] = (b.iloc[k] - x_min) / (x_max - x_min)
    
    return data1, data2

A = ['RPM1', 'RPM2', 'RPM3', 'RPM4', 'RPM5', 'RPM6', 'P', 'Q', 'R', 'Phi', 'Theta', 'Psi']

X_train, X_test = MinmaxNorm(X_train, X_test, A)

X_train = X_train.values
X_test = X_test.values

# print(X_train[8], X_train.shape)
# print(X_test[8], X_test.shape)
# Out:
# [0.60630118 0.05871533 0.         0.39369882 0.94128467 1.
#  0.38188937 0.5978608  0.85474281 0.85450307 0.80077468 0.42103086] (17762, 12)
# [0.05871533 0.39369882 0.80587303 0.94128467 0.60630118 0.19412697
#  0.65617113 0.51031775 0.28043487 0.69725615 0.73418171 0.71461153] (20000, 12)

# %%
input_dim = 12
latent_dim = 4

class Autoencoder(Model):
    def __init__(self, latent_dim):
        super(Autoencoder, self).__init__()
        self.latent_dim = latent_dim
        self.encoder = Sequential([
            # layers.Dense(8, activation='sigmoid',
            #             activity_regularizer=regularizers.l2(10e-3)),
            layers.Dense(8, activation='sigmoid'),
            layers.Dense(latent_dim, activation='relu'),
        ])
        self.decoder = Sequential([
            layers.Dense(8, activation='relu'),
            layers.Dense(input_dim, activation='relu'),
        ])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
autoencoder = Autoencoder(latent_dim)
autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())
callback = EarlyStopping(monitor='val_loss', patience=3)
checkpointer = ModelCheckpoint(filepath="AE_h8_l4",
                               monitor='val_loss',
                               verbose=0,
                               save_best_only=True)

tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

batch_size = 12
nb_epochs = 100
history = autoencoder.fit(X_train, X_train,
                        epochs=nb_epochs,
                        batch_size=batch_size,
                        shuffle=True,
                        validation_split=0.4,
                        callbacks=[checkpointer, tensorboard]).history

autoencoder.summary()
# Out:
# Epoch 1/100
# 837/889 [===========================>..] - ETA: 0s - loss: 0.2147INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.2128 - val_loss: 0.1792
# Epoch 2/100
# 854/889 [===========================>..] - ETA: 0s - loss: 0.1734INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1734 - val_loss: 0.1694
# Epoch 3/100
# 832/889 [===========================>..] - ETA: 0s - loss: 0.1676INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1676 - val_loss: 0.1659
# Epoch 4/100
# 835/889 [===========================>..] - ETA: 0s - loss: 0.1660INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1661 - val_loss: 0.1654
# Epoch 5/100
# 861/889 [============================>.] - ETA: 0s - loss: 0.1658INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1658 - val_loss: 0.1652
# Epoch 6/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1657 - val_loss: 0.1653
# Epoch 7/100
# 866/889 [============================>.] - ETA: 0s - loss: 0.1655INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1656 - val_loss: 0.1651
# Epoch 8/100
# 825/889 [==========================>...] - ETA: 0s - loss: 0.1658INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1655 - val_loss: 0.1650
# Epoch 9/100
# 854/889 [===========================>..] - ETA: 0s - loss: 0.1653INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1655 - val_loss: 0.1650
# Epoch 10/100
# 869/889 [============================>.] - ETA: 0s - loss: 0.1654INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1654 - val_loss: 0.1649
# Epoch 11/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1654 - val_loss: 0.1649
# Epoch 12/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1653 - val_loss: 0.1649
# Epoch 13/100
# 866/889 [============================>.] - ETA: 0s - loss: 0.1650INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1651 - val_loss: 0.1646
# Epoch 14/100
# 829/889 [==========================>...] - ETA: 0s - loss: 0.1650INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1650 - val_loss: 0.1644
# Epoch 15/100
# 832/889 [===========================>..] - ETA: 0s - loss: 0.1648INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1649 - val_loss: 0.1643
# Epoch 16/100
# 889/889 [==============================] - ETA: 0s - loss: 0.1647INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1647 - val_loss: 0.1642
# Epoch 17/100
# 882/889 [============================>.] - ETA: 0s - loss: 0.1646INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1646 - val_loss: 0.1640
# Epoch 18/100
# 841/889 [===========================>..] - ETA: 0s - loss: 0.1645INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1644 - val_loss: 0.1639
# Epoch 19/100
# 878/889 [============================>.] - ETA: 0s - loss: 0.1643INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 1s 2ms/step - loss: 0.1643 - val_loss: 0.1637
# Epoch 20/100
# 874/889 [============================>.] - ETA: 0s - loss: 0.1641INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1641 - val_loss: 0.1634
# Epoch 21/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1639 - val_loss: 0.1636
# Epoch 22/100
# 887/889 [============================>.] - ETA: 0s - loss: 0.1637INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1637 - val_loss: 0.1632
# Epoch 23/100
# 842/889 [===========================>..] - ETA: 0s - loss: 0.1636INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1635 - val_loss: 0.1629
# Epoch 24/100
# 878/889 [============================>.] - ETA: 0s - loss: 0.1633INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1633 - val_loss: 0.1628
# Epoch 25/100
# 837/889 [===========================>..] - ETA: 0s - loss: 0.1633INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1632 - val_loss: 0.1627
# Epoch 26/100
# 852/889 [===========================>..] - ETA: 0s - loss: 0.1632INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1631 - val_loss: 0.1626
# Epoch 27/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1631 - val_loss: 0.1626
# Epoch 28/100
# 821/889 [==========================>...] - ETA: 0s - loss: 0.1628INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1630 - val_loss: 0.1625
# Epoch 29/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1629 - val_loss: 0.1625
# Epoch 30/100
# 878/889 [============================>.] - ETA: 0s - loss: 0.1629INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1629 - val_loss: 0.1623
# Epoch 31/100
# 823/889 [==========================>...] - ETA: 0s - loss: 0.1629INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1628 - val_loss: 0.1623
# Epoch 32/100
# 881/889 [============================>.] - ETA: 0s - loss: 0.1628INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1628 - val_loss: 0.1623
# Epoch 33/100
# 828/889 [==========================>...] - ETA: 0s - loss: 0.1627INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1627 - val_loss: 0.1622
# Epoch 34/100
# 873/889 [============================>.] - ETA: 0s - loss: 0.1627INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1627 - val_loss: 0.1622
# Epoch 35/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1627 - val_loss: 0.1622
# Epoch 36/100
# 864/889 [============================>.] - ETA: 0s - loss: 0.1626INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1626 - val_loss: 0.1621
# Epoch 37/100
# 868/889 [============================>.] - ETA: 0s - loss: 0.1628INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1626 - val_loss: 0.1621
# Epoch 38/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1626 - val_loss: 0.1621
# Epoch 39/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1625 - val_loss: 0.1621
# Epoch 40/100
# 887/889 [============================>.] - ETA: 0s - loss: 0.1625INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1625 - val_loss: 0.1620
# Epoch 41/100
# 822/889 [==========================>...] - ETA: 0s - loss: 0.1624INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1625 - val_loss: 0.1620
# Epoch 42/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1625 - val_loss: 0.1620
# Epoch 43/100
# 848/889 [===========================>..] - ETA: 0s - loss: 0.1626INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1625 - val_loss: 0.1620
# Epoch 44/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1625 - val_loss: 0.1620
# Epoch 45/100
# 858/889 [===========================>..] - ETA: 0s - loss: 0.1624INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1624 - val_loss: 0.1619
# Epoch 46/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1624 - val_loss: 0.1620
# Epoch 47/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1624 - val_loss: 0.1620
# Epoch 48/100
# 845/889 [===========================>..] - ETA: 0s - loss: 0.1550INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1545 - val_loss: 0.1427
# Epoch 49/100
# 831/889 [===========================>..] - ETA: 0s - loss: 0.1406INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1406 - val_loss: 0.1390
# Epoch 50/100
# 872/889 [============================>.] - ETA: 0s - loss: 0.1398INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1397 - val_loss: 0.1387
# Epoch 51/100
# 831/889 [===========================>..] - ETA: 0s - loss: 0.1393INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1395 - val_loss: 0.1384
# Epoch 52/100
# 888/889 [============================>.] - ETA: 0s - loss: 0.1393INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1393 - val_loss: 0.1382
# Epoch 53/100
# 832/889 [===========================>..] - ETA: 0s - loss: 0.1390INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1391 - val_loss: 0.1381
# Epoch 54/100
# 858/889 [===========================>..] - ETA: 0s - loss: 0.1390INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1389 - val_loss: 0.1380
# Epoch 55/100
# 853/889 [===========================>..] - ETA: 0s - loss: 0.1388INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1388 - val_loss: 0.1378
# Epoch 56/100
# 888/889 [============================>.] - ETA: 0s - loss: 0.1387INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1388 - val_loss: 0.1377
# Epoch 57/100
# 864/889 [============================>.] - ETA: 0s - loss: 0.1387INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1387 - val_loss: 0.1377
# Epoch 58/100
# 829/889 [==========================>...] - ETA: 0s - loss: 0.1385INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1386 - val_loss: 0.1376
# Epoch 59/100
# 850/889 [===========================>..] - ETA: 0s - loss: 0.1388INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1386 - val_loss: 0.1375
# Epoch 60/100
# 864/889 [============================>.] - ETA: 0s - loss: 0.1385INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1385 - val_loss: 0.1375
# Epoch 61/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1385 - val_loss: 0.1377
# Epoch 62/100
# 885/889 [============================>.] - ETA: 0s - loss: 0.1384INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 1s 2ms/step - loss: 0.1384 - val_loss: 0.1375
# Epoch 63/100
# 852/889 [===========================>..] - ETA: 0s - loss: 0.1384INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1384 - val_loss: 0.1374
# Epoch 64/100
# 848/889 [===========================>..] - ETA: 0s - loss: 0.1381INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1383 - val_loss: 0.1374
# Epoch 65/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1383 - val_loss: 0.1374
# Epoch 66/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1383 - val_loss: 0.1375
# Epoch 67/100
# 886/889 [============================>.] - ETA: 0s - loss: 0.1383INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1383 - val_loss: 0.1373
# Epoch 68/100
# 856/889 [===========================>..] - ETA: 0s - loss: 0.1382INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1382 - val_loss: 0.1373
# Epoch 69/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1382 - val_loss: 0.1375
# Epoch 70/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1382 - val_loss: 0.1373
# Epoch 71/100
# 882/889 [============================>.] - ETA: 0s - loss: 0.1382INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1382 - val_loss: 0.1373
# Epoch 72/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1382 - val_loss: 0.1375
# Epoch 73/100
# 882/889 [============================>.] - ETA: 0s - loss: 0.1381INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1382 - val_loss: 0.1373
# Epoch 74/100
# 834/889 [===========================>..] - ETA: 0s - loss: 0.1382INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1382 - val_loss: 0.1372
# Epoch 75/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1381 - val_loss: 0.1374
# Epoch 76/100
# 831/889 [===========================>..] - ETA: 0s - loss: 0.1381INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1381 - val_loss: 0.1372
# Epoch 77/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1381 - val_loss: 0.1372
# Epoch 78/100
# 851/889 [===========================>..] - ETA: 0s - loss: 0.1381INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1381 - val_loss: 0.1372
# Epoch 79/100
# 860/889 [============================>.] - ETA: 0s - loss: 0.1380INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1381 - val_loss: 0.1371
# Epoch 80/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1380 - val_loss: 0.1372
# Epoch 81/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1380 - val_loss: 0.1371
# Epoch 82/100
# 884/889 [============================>.] - ETA: 0s - loss: 0.1380INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1380 - val_loss: 0.1371
# Epoch 83/100
# 840/889 [===========================>..] - ETA: 0s - loss: 0.1380INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1380 - val_loss: 0.1370
# Epoch 84/100
# 874/889 [============================>.] - ETA: 0s - loss: 0.1380INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1380 - val_loss: 0.1370
# Epoch 85/100
# 875/889 [============================>.] - ETA: 0s - loss: 0.1380INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1379 - val_loss: 0.1370
# Epoch 86/100
# 879/889 [============================>.] - ETA: 0s - loss: 0.1379INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1379 - val_loss: 0.1369
# Epoch 87/100
# 847/889 [===========================>..] - ETA: 0s - loss: 0.1380INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1379 - val_loss: 0.1369
# Epoch 88/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1379 - val_loss: 0.1370
# Epoch 89/100
# 880/889 [============================>.] - ETA: 0s - loss: 0.1379INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1378 - val_loss: 0.1368
# Epoch 90/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1378 - val_loss: 0.1369
# Epoch 91/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1378 - val_loss: 0.1370
# Epoch 92/100
# 847/889 [===========================>..] - ETA: 0s - loss: 0.1378INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1378 - val_loss: 0.1368
# Epoch 93/100
# 863/889 [============================>.] - ETA: 0s - loss: 0.1378INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1378 - val_loss: 0.1368
# Epoch 94/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1377 - val_loss: 0.1369
# Epoch 95/100
# 847/889 [===========================>..] - ETA: 0s - loss: 0.1377INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1377 - val_loss: 0.1367
# Epoch 96/100
# 874/889 [============================>.] - ETA: 0s - loss: 0.1377INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 889/889 [==============================] - 2s 2ms/step - loss: 0.1377 - val_loss: 0.1367
# Epoch 97/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1377 - val_loss: 0.1368
# Epoch 98/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1377 - val_loss: 0.1368
# Epoch 99/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1377 - val_loss: 0.1367
# Epoch 100/100
# 889/889 [==============================] - 1s 1ms/step - loss: 0.1377 - val_loss: 0.1368
# Model: "autoencoder_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_6 (Sequential)   (None, 4)                 140
#
#  sequential_7 (Sequential)   (None, 12)                148
#
# =================================================================
# Total params: 288
# Trainable params: 288
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.plot(range(nb_epochs), history['loss'], label='Training Loss')
plt.plot(range(nb_epochs), history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
'''
오류 분포표
- 정밀도(Precision)
: 참인데 참이라고 예측한 데이터 / 참이라고 예측한 데이터
: 정상인데 정상이라고 예측한 데이터 / 정상이라고 예측한 데이터
- 재현율(Recall)
: 참인데 참이라고 예측한 데이터 / 실제로 참인 데이터
: 정상인테 정상이라고 예측한 데이터 / 실제로 정상인 데이터
'''
predictions1 = autoencoder.predict(X_train)
predictions2 = autoencoder.predict(X_test)
mse = np.mean(np.power((X_train - predictions1), 2), axis=1)
aver_rmse = np.mean(np.sqrt(mse), axis=0)
thresholds = max(mse)
mse2 = np.mean(np.power((X_test - predictions2), 2), axis=1)

error_df = pd.DataFrame({'reconstruction_error': mse2,
                        'true_class': y_test})
# print(error_df.shape)
# error_df.describe()
error_df.reconstruction_error = error_df.reconstruction_error >= thresholds
error_df['reconstruction_error'] = error_df['reconstruction_error'].astype(int)
    
# print(error_df.shape[0])
print(error_df.reconstruction_error)
# print(error_df)
# Out:
# 556/556 [==============================] - 0s 598us/step
# 625/625 [==============================] - 0s 760us/step
# 32823    0
# 16298    0
# 28505    0
# 6689     1
# 26893    0
#         ..
# 14965    0
# 22133    0
# 5442     0
# 21456    0
# 1760     0
# Name: reconstruction_error, Length: 20000, dtype: int32

# %%
# 정상 거래 데이터들의 재구성 오류 분포
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)
ax.set_title('normal reconstruction error distribution')
ax.set_xlabel('reconstruction error')
ax.set_ylabel('data')
ax.set_xlim([0, 1])
# Out:
# (0.0, 1.0)

# %%
# 이상 거래 데이터들의 재구성 오류 분포
fig = plt.figure()
ax = fig.add_subplot(111)
Abnormal_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(Abnormal_error_df.reconstruction_error.values, bins=10)
ax.set_title('abnormal reconstruction error distribution')
ax.set_xlabel('reconstruction error')
ax.set_ylabel('data')
plt.show();

# %%
# ROC 곡선을 통한 평가
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)
# ROC 곡선은 이진 분류기(binary classifier)의 성능을 평가하는 유용한 도구이다.
# 굉정히 불균형한 데이터셋을 가지고 있기 때문에 일반적인 경우가 아님
fpr, tpr, thresholds2 = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)
F1_score = f1_score(error_df.true_class, error_df.reconstruction_error)
print(F1_score)
# Out:
# 0.9935655646771688

# %%
predictions1 = autoencoder.predict(X_train)
mse = np.mean(np.power((X_train - predictions1), 2), axis=1)
aver_rmse = np.mean(np.sqrt(mse), axis=0)
thresholds = max(mse)

# ROC curve
plt.figure()
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
# plt.xlim([-0.001, 1])
# plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# precision-recall curve
precision, recall, th2 = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='F1 score = %0.4f'% F1_score)
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(loc='lower left')
plt.show();

# Generate confusion matrix
# y_pred = [1 if e > thresholds else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(y_test, error_df.reconstruction_error)
LABELS = ["Normal", "Abnormal"]
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, 
                        annot=True, fmt="d", annot_kws={'size': 20}, cmap="YlGnBu", 
                        vmin=0, vmax=4000);
plt.title("Confusion matrix")
plt.xlabel('Predicted class')
plt.ylabel('True class')
plt.show()
# Out:
# 556/556 [==============================] - 0s 565us/step

# %%
# #
# predictions = autoencoder.predict(X_train)
# square_error1 = np.power((X_train - predictions), 2)
# groups = error_df.groupby('true_class')
# fig, ax = plt.subplots()

# for name, group in groups:
#     ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
#             label= "Abnormal" if name == 1 else "Normal")
# ax.hlines(thresholds, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
# ax.legend()
# plt.title("Reconstruction error for different classes")
# plt.ylabel("Reconstruction error")
# plt.xlabel("Data point index")
# plt.show();

# fig, ax = plt.subplots()

# for name, group in groups:
#     ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
#             label= "Abnormal" if name == 1 else "Normal")
# ax.hlines(thresholds, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
# ax.legend()
# plt.title("Reconstruction error for different classes")
# plt.ylabel("Reconstruction error")
# plt.xlabel("Data point index")
# plt.ylim([0, 10])
# plt.show();

# y_pred = [1 if e > thresholds else 0 for e in error_df.reconstruction_error.values]
# conf_matrix = confusion_matrix(error_df.true_class, y_pred)
# plt.figure(figsize=(12, 12))
# sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
# plt.title("Confusion matrix")
# plt.ylabel('True class')
# plt.xlabel('Predicted class')
# plt.show()
