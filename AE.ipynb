# %%
from sklearn.mixture import GaussianMixture
from sklearn.metrics import precision_score, recall_score, f1_score, auc
from sklearn.model_selection import train_test_split
from keras import layers, Model
from keras.models import Sequential, load_model
import numpy as np
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping
from keras import regularizers, layers, losses
from keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn.metrics import precision_recall_curve, confusion_matrix, roc_curve, PrecisionRecallDisplay
from keras.utils import plot_model
import pandas as pd
import seaborn as sns
import joblib

# %%
# Generate some sample data for the autoencoder
# x_train = np.random.rand(1000, 12)
# x_test = np.random.rand(100, 12)

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

RANDOM_SEED = 42

df = pd.read_csv("Autoencoder_wind.csv")  
print(df.shape)

LABELS = ["Normal", "Abnormal"]

count_classes =pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Data Class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Data")
plt.show();

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from cmath import pi

data = df.drop(['Time'], axis=1)
y_true = df['Class']

r2d = 180/pi

data['P'] = r2d * data['P']
data['Q'] = r2d * data['Q']
data['R'] = r2d * data['R']
data['Phi'] = r2d * data['Phi']
data['Theta'] = r2d * data['Theta']
data['Psi'] = r2d * data['Psi']
# Out:
# (40000, 14)

# %%
X_train, X_test = train_test_split(data, test_size=0.5, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
y_train = X_train['Class']
X_train = pd.DataFrame(X_train)
X_train = X_train.drop(['Class'], axis=1)

# X_test = X_test[X_test.Class == 0]
y_test = X_test['Class']
X_test = pd.DataFrame(X_test)
X_test = X_test.drop(['Class'], axis=1)

def normalize(label):
    str = StandardScaler()
    str.fit(X_train[label].values.reshape(-1, 1))
    X_train[label] = str.transform(X_train[label].values.reshape(-1, 1))
    X_test[label] = str.transform(X_test[label].values.reshape(-1, 1))

def normalize1(label):
    str = MinMaxScaler()
    str.fit(X_train[label].values.reshape(-1, 1))
    X_train[label] = str.transform(X_train[label].values.reshape(-1, 1))
    X_test[label] = str.transform(X_test[label].values.reshape(-1, 1))

A = ['RPM1', 'RPM2', 'RPM3', 'RPM4', 'RPM5', 'RPM6', 'P', 'Q', 'R', 'Phi', 'Theta', 'Psi']

for i in A:
    normalize1(i)

X_train = X_train.values
X_test = X_test.values

# %%
input_dim = 12
latent_dim = 4

class Autoencoder(Model):
    def __init__(self, latent_dim):
        super(Autoencoder, self).__init__()
        self.latent_dim = latent_dim
        self.encoder = Sequential([
            # layers.Dense(8, activation='sigmoid',
            #             activity_regularizer=regularizers.l2(10e-3)),
            layers.Dense(8, activation='sigmoid'),
            layers.Dense(latent_dim, activation='relu'),
        ])
        self.decoder = Sequential([
            layers.Dense(8, activation='relu'),
            layers.Dense(input_dim, activation='tanh'),
        ])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
autoencoder = Autoencoder(latent_dim)
autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())
callback = EarlyStopping(monitor='val_loss', patience=3)
checkpointer = ModelCheckpoint(filepath="AE",
                               monitor='val_loss',
                               verbose=0,
                               save_best_only=True)

tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

batch_size = 4
nb_epochs = 100
history = autoencoder.fit(X_train, X_train,
                        epochs=nb_epochs,
                        batch_size=batch_size,
                        shuffle=True,
                        validation_split=0.4,
                        callbacks=[checkpointer, tensorboard]).history

autoencoder.summary()
# Out:
# Epoch 1/100
# 2653/2665 [============================>.] - ETA: 0s - loss: 0.5511INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 5s 2ms/step - loss: 0.5506 - val_loss: 0.4241
# Epoch 2/100
# 2617/2665 [============================>.] - ETA: 0s - loss: 0.4116INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.4112 - val_loss: 0.3960
# Epoch 3/100
# 2643/2665 [============================>.] - ETA: 0s - loss: 0.3938INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.3936 - val_loss: 0.3810
# Epoch 4/100
# 2620/2665 [============================>.] - ETA: 0s - loss: 0.3807INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.3806 - val_loss: 0.3713
# Epoch 5/100
# 2619/2665 [============================>.] - ETA: 0s - loss: 0.3701INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.3698 - val_loss: 0.3625
# Epoch 6/100
# 2620/2665 [============================>.] - ETA: 0s - loss: 0.3623INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.3621 - val_loss: 0.3555
# Epoch 7/100
# 2661/2665 [============================>.] - ETA: 0s - loss: 0.3563INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 5s 2ms/step - loss: 0.3563 - val_loss: 0.3512
# Epoch 8/100
# 2614/2665 [============================>.] - ETA: 0s - loss: 0.3517INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 5s 2ms/step - loss: 0.3514 - val_loss: 0.3463
# Epoch 9/100
# 2647/2665 [============================>.] - ETA: 0s - loss: 0.3462INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.3464 - val_loss: 0.3421
# Epoch 10/100
# 2662/2665 [============================>.] - ETA: 0s - loss: 0.3414INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.3413 - val_loss: 0.3363
# Epoch 11/100
# 2632/2665 [============================>.] - ETA: 0s - loss: 0.3367INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 5s 2ms/step - loss: 0.3363 - val_loss: 0.3324
# Epoch 12/100
# 2624/2665 [============================>.] - ETA: 0s - loss: 0.3325INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.3321 - val_loss: 0.3295
# Epoch 13/100
# 2608/2665 [============================>.] - ETA: 0s - loss: 0.3284INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.3285 - val_loss: 0.3254
# Epoch 14/100
# 2613/2665 [============================>.] - ETA: 0s - loss: 0.3232INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.3230 - val_loss: 0.3205
# Epoch 15/100
# 2631/2665 [============================>.] - ETA: 0s - loss: 0.3192INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.3189 - val_loss: 0.3166
# Epoch 16/100
# 2642/2665 [============================>.] - ETA: 0s - loss: 0.3161INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 5s 2ms/step - loss: 0.3160 - val_loss: 0.3153
# Epoch 17/100
# 2603/2665 [============================>.] - ETA: 0s - loss: 0.3135INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.3137 - val_loss: 0.3129
# Epoch 18/100
# 2632/2665 [============================>.] - ETA: 0s - loss: 0.3120INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.3121 - val_loss: 0.3116
# Epoch 19/100
# 2653/2665 [============================>.] - ETA: 0s - loss: 0.3111INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.3113 - val_loss: 0.3113
# Epoch 20/100
# 2616/2665 [============================>.] - ETA: 0s - loss: 0.3096INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.3100 - val_loss: 0.3087
# Epoch 21/100
# 2612/2665 [============================>.] - ETA: 0s - loss: 0.3085INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.3082 - val_loss: 0.3070
# Epoch 22/100
# 2620/2665 [============================>.] - ETA: 0s - loss: 0.3064INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.3064 - val_loss: 0.3051
# Epoch 23/100
# 2647/2665 [============================>.] - ETA: 0s - loss: 0.3048INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.3049 - val_loss: 0.3047
# Epoch 24/100
# 2661/2665 [============================>.] - ETA: 0s - loss: 0.3031INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 5s 2ms/step - loss: 0.3032 - val_loss: 0.3033
# Epoch 25/100
# 2606/2665 [============================>.] - ETA: 0s - loss: 0.3019INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.3019 - val_loss: 0.3017
# Epoch 26/100
# 2617/2665 [============================>.] - ETA: 0s - loss: 0.3004INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.3006 - val_loss: 0.2999
# Epoch 27/100
# 2646/2665 [============================>.] - ETA: 0s - loss: 0.2991INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2989 - val_loss: 0.2995
# Epoch 28/100
# 2624/2665 [============================>.] - ETA: 0s - loss: 0.2972INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2974 - val_loss: 0.2974
# Epoch 29/100
# 2635/2665 [============================>.] - ETA: 0s - loss: 0.2956INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2957 - val_loss: 0.2950
# Epoch 30/100
# 2649/2665 [============================>.] - ETA: 0s - loss: 0.2944INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2943 - val_loss: 0.2945
# Epoch 31/100
# 2665/2665 [==============================] - ETA: 0s - loss: 0.2931INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2931 - val_loss: 0.2926
# Epoch 32/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2921 - val_loss: 0.2929
# Epoch 33/100
# 2660/2665 [============================>.] - ETA: 0s - loss: 0.2912INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2912 - val_loss: 0.2915
# Epoch 34/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.2905 - val_loss: 0.2934
# Epoch 35/100
# 2620/2665 [============================>.] - ETA: 0s - loss: 0.2902INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 5s 2ms/step - loss: 0.2901 - val_loss: 0.2906
# Epoch 36/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2892 - val_loss: 0.2913
# Epoch 37/100
# 2634/2665 [============================>.] - ETA: 0s - loss: 0.2889INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2889 - val_loss: 0.2903
# Epoch 38/100
# 2633/2665 [============================>.] - ETA: 0s - loss: 0.2886INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 5s 2ms/step - loss: 0.2885 - val_loss: 0.2881
# Epoch 39/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2882 - val_loss: 0.2888
# Epoch 40/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2878 - val_loss: 0.2897
# Epoch 41/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2873 - val_loss: 0.2885
# Epoch 42/100
# 2634/2665 [============================>.] - ETA: 0s - loss: 0.2867INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 5s 2ms/step - loss: 0.2868 - val_loss: 0.2878
# Epoch 43/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2863 - val_loss: 0.2881
# Epoch 44/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2858 - val_loss: 0.2882
# Epoch 45/100
# 2615/2665 [============================>.] - ETA: 0s - loss: 0.2857INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 5s 2ms/step - loss: 0.2855 - val_loss: 0.2859
# Epoch 46/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2849 - val_loss: 0.2865
# Epoch 47/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2844 - val_loss: 0.2874
# Epoch 48/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2842 - val_loss: 0.2879
# Epoch 49/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2837 - val_loss: 0.2860
# Epoch 50/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2834 - val_loss: 0.2867
# Epoch 51/100
# 2656/2665 [============================>.] - ETA: 0s - loss: 0.2829INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2831 - val_loss: 0.2853
# Epoch 52/100
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2828 - val_loss: 0.2856
# Epoch 53/100
# 2653/2665 [============================>.] - ETA: 0s - loss: 0.2822INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2824 - val_loss: 0.2847
# Epoch 54/100
# 2661/2665 [============================>.] - ETA: 0s - loss: 0.2818INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 5s 2ms/step - loss: 0.2818 - val_loss: 0.2838
# Epoch 55/100
# 2625/2665 [============================>.] - ETA: 0s - loss: 0.2818INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 5s 2ms/step - loss: 0.2815 - val_loss: 0.2834
# Epoch 56/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2811 - val_loss: 0.2834
# Epoch 57/100
# 2650/2665 [============================>.] - ETA: 0s - loss: 0.2809INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2810 - val_loss: 0.2831
# Epoch 58/100
# 2635/2665 [============================>.] - ETA: 0s - loss: 0.2803INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2807 - val_loss: 0.2820
# Epoch 59/100
# 2620/2665 [============================>.] - ETA: 0s - loss: 0.2805INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2797 - val_loss: 0.2805
# Epoch 60/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2793 - val_loss: 0.2813
# Epoch 61/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2787 - val_loss: 0.2812
# Epoch 62/100
# 2624/2665 [============================>.] - ETA: 0s - loss: 0.2791INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 5s 2ms/step - loss: 0.2787 - val_loss: 0.2798
# Epoch 63/100
# 2606/2665 [============================>.] - ETA: 0s - loss: 0.2781INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2782 - val_loss: 0.2796
# Epoch 64/100
# 2639/2665 [============================>.] - ETA: 0s - loss: 0.2778INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 5s 2ms/step - loss: 0.2779 - val_loss: 0.2790
# Epoch 65/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2777 - val_loss: 0.2796
# Epoch 66/100
# 2658/2665 [============================>.] - ETA: 0s - loss: 0.2769INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 5s 2ms/step - loss: 0.2770 - val_loss: 0.2781
# Epoch 67/100
# 2612/2665 [============================>.] - ETA: 0s - loss: 0.2768INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 5s 2ms/step - loss: 0.2768 - val_loss: 0.2773
# Epoch 68/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2767 - val_loss: 0.2773
# Epoch 69/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2762 - val_loss: 0.2789
# Epoch 70/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.2759 - val_loss: 0.2779
# Epoch 71/100
# 2653/2665 [============================>.] - ETA: 0s - loss: 0.2759INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2758 - val_loss: 0.2769
# Epoch 72/100
# 2663/2665 [============================>.] - ETA: 0s - loss: 0.2754INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 5s 2ms/step - loss: 0.2754 - val_loss: 0.2758
# Epoch 73/100
# 2631/2665 [============================>.] - ETA: 0s - loss: 0.2746INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2747 - val_loss: 0.2753
# Epoch 74/100
# 2624/2665 [============================>.] - ETA: 0s - loss: 0.2752INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2747 - val_loss: 0.2748
# Epoch 75/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2744 - val_loss: 0.2757
# Epoch 76/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2738 - val_loss: 0.2764
# Epoch 77/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.2740 - val_loss: 0.2756
# Epoch 78/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2738 - val_loss: 0.2752
# Epoch 79/100
# 2614/2665 [============================>.] - ETA: 0s - loss: 0.2738INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2736 - val_loss: 0.2738
# Epoch 80/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2736 - val_loss: 0.2743
# Epoch 81/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2734 - val_loss: 0.2756
# Epoch 82/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2735 - val_loss: 0.2754
# Epoch 83/100
# 2658/2665 [============================>.] - ETA: 0s - loss: 0.2735INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2734 - val_loss: 0.2737
# Epoch 84/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2729 - val_loss: 0.2742
# Epoch 85/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2729 - val_loss: 0.2738
# Epoch 86/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2729 - val_loss: 0.2747
# Epoch 87/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2728 - val_loss: 0.2760
# Epoch 88/100
# 2626/2665 [============================>.] - ETA: 0s - loss: 0.2727INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2729 - val_loss: 0.2729
# Epoch 89/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2725 - val_loss: 0.2743
# Epoch 90/100
# 2648/2665 [============================>.] - ETA: 0s - loss: 0.2724INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2725 - val_loss: 0.2728
# Epoch 91/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2723 - val_loss: 0.2748
# Epoch 92/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2726 - val_loss: 0.2734
# Epoch 93/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2720 - val_loss: 0.2759
# Epoch 94/100
# 2608/2665 [============================>.] - ETA: 0s - loss: 0.2719INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2719 - val_loss: 0.2720
# Epoch 95/100
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2721 - val_loss: 0.2733
# Epoch 96/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2720 - val_loss: 0.2740
# Epoch 97/100
# 2647/2665 [============================>.] - ETA: 0s - loss: 0.2717INFO:tensorflow:Assets written to: AE\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.2720 - val_loss: 0.2719
# Epoch 98/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2716 - val_loss: 0.2724
# Epoch 99/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2718 - val_loss: 0.2723
# Epoch 100/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.2715 - val_loss: 0.2737
# Model: "autoencoder_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_2 (Sequential)   (None, 4)                 140
#
#  sequential_3 (Sequential)   (None, 12)                148
#
# =================================================================
# Total params: 288
# Trainable params: 288
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.plot(range(nb_epochs), history['loss'], label='Training Loss')
plt.plot(range(nb_epochs), history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
'''
오류 분포표
- 정밀도(Precision)
: 참인데 참이라고 예측한 데이터 / 참이라고 예측한 데이터
: 정상인데 정상이라고 예측한 데이터 / 정상이라고 예측한 데이터
- 재현율(Recall)
: 참인데 참이라고 예측한 데이터 / 실제로 참인 데이터
: 정상인테 정상이라고 예측한 데이터 / 실제로 정상인 데이터
'''
predictions1 = autoencoder.predict(X_train)
predictions2 = autoencoder.predict(X_test)
mse = np.mean(np.power((X_train - predictions1), 2), axis=1)
aver_rmse = np.mean(np.sqrt(mse), axis=0)
thresholds = max(mse)
mse2 = np.mean(np.power((X_test - predictions2), 2), axis=1)

error_df = pd.DataFrame({'reconstruction_error': mse2,
                        'true_class': y_test})
# print(error_df.shape)
# error_df.describe()
error_df.reconstruction_error = error_df.reconstruction_error >= thresholds
error_df['reconstruction_error'] = error_df['reconstruction_error'].astype(int)
    
# print(error_df.shape[0])
print(error_df.reconstruction_error)
# print(error_df)
# Out:
# 556/556 [==============================] - 0s 665us/step
# 625/625 [==============================] - 0s 761us/step
# 32823    0
# 16298    0
# 28505    0
# 6689     1
# 26893    0
#         ..
# 14965    0
# 22133    0
# 5442     0
# 21456    0
# 1760     0
# Name: reconstruction_error, Length: 20000, dtype: int32

# %%
# 정상 거래 데이터들의 재구성 오류 분포
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)
ax.set_title('normal reconstruction error distribution')
ax.set_xlabel('reconstruction error')
ax.set_ylabel('data')
ax.set_xlim([0, 1])
# Out:
# (0.0, 1.0)

# %%
# 이상 거래 데이터들의 재구성 오류 분포
fig = plt.figure()
ax = fig.add_subplot(111)
Abnormal_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(Abnormal_error_df.reconstruction_error.values, bins=10)
ax.set_title('abnormal reconstruction error distribution')
ax.set_xlabel('reconstruction error')
ax.set_ylabel('data')
plt.show();

# %%
# ROC 곡선을 통한 평가
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)
# ROC 곡선은 이진 분류기(binary classifier)의 성능을 평가하는 유용한 도구이다.
# 굉정히 불균형한 데이터셋을 가지고 있기 때문에 일반적인 경우가 아님
fpr, tpr, thresholds2 = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)
F1_score = f1_score(error_df.true_class, error_df.reconstruction_error)
print(F1_score)
# Out:
# 0.9969012837538733

# %%
predictions1 = autoencoder.predict(X_train)
mse = np.mean(np.power((X_train - predictions1), 2), axis=1)
aver_rmse = np.mean(np.sqrt(mse), axis=0)
thresholds = max(mse)

# ROC curve
plt.figure()
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
# plt.xlim([-0.001, 1])
# plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# precision-recall curve
precision, recall, th2 = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='F1 score = %0.4f'% F1_score)
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(loc='lower left')
plt.show();

# Generate confusion matrix
# y_pred = [1 if e > thresholds else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(y_test, error_df.reconstruction_error)
LABELS = ["Normal", "Abnormal"]
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, 
                        annot=True, fmt="d", annot_kws={'size': 20}, cmap="YlGnBu", 
                        vmin=0, vmax=4000);
plt.title("Confusion matrix")
plt.xlabel('Predicted class')
plt.ylabel('True class')
plt.show()
# Out:
# 556/556 [==============================] - 0s 682us/step

# %%
# #
# predictions = autoencoder.predict(X_train)
# square_error1 = np.power((X_train - predictions), 2)
# groups = error_df.groupby('true_class')
# fig, ax = plt.subplots()

# for name, group in groups:
#     ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
#             label= "Abnormal" if name == 1 else "Normal")
# ax.hlines(thresholds, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
# ax.legend()
# plt.title("Reconstruction error for different classes")
# plt.ylabel("Reconstruction error")
# plt.xlabel("Data point index")
# plt.show();

# fig, ax = plt.subplots()

# for name, group in groups:
#     ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
#             label= "Abnormal" if name == 1 else "Normal")
# ax.hlines(thresholds, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
# ax.legend()
# plt.title("Reconstruction error for different classes")
# plt.ylabel("Reconstruction error")
# plt.xlabel("Data point index")
# plt.ylim([0, 10])
# plt.show();

# y_pred = [1 if e > thresholds else 0 for e in error_df.reconstruction_error.values]
# conf_matrix = confusion_matrix(error_df.true_class, y_pred)
# plt.figure(figsize=(12, 12))
# sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
# plt.title("Confusion matrix")
# plt.ylabel('True class')
# plt.xlabel('Predicted class')
# plt.show()
