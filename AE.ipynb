# %%
from sklearn.mixture import GaussianMixture
from sklearn.metrics import precision_score, recall_score, f1_score, auc
from sklearn.model_selection import train_test_split
from keras import layers, Model
from keras.models import Sequential, load_model
import numpy as np
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping
from keras import regularizers, layers, losses
from keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn.metrics import precision_recall_curve, confusion_matrix, roc_curve, PrecisionRecallDisplay
from keras.utils import plot_model
import pandas as pd
import seaborn as sns
import joblib

# %%
# Generate some sample data for the autoencoder
# x_train = np.random.rand(1000, 12)
# x_test = np.random.rand(100, 12)

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

RANDOM_SEED = 42

df = pd.read_csv("Autoencoder1.csv")  
print(df.shape)

LABELS = ["Normal", "Abnormal"]

count_classes =pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Data Class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Data")
plt.show();

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from cmath import pi

data = df.drop(['Time'], axis=1)
y_true = df['Class']

r2d = 180/pi

data['P'] = r2d * data['P']
data['Q'] = r2d * data['Q']
data['R'] = r2d * data['R']
data['Phi'] = r2d * data['Phi']
data['Theta'] = r2d * data['Theta']
data['Psi'] = r2d * data['Psi']
# Out:
# (39000, 14)

# %%
X_train, X_test = train_test_split(data, test_size=0.5, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
y_train = X_train['Class']
X_train = pd.DataFrame(X_train)
X_train = X_train.drop(['Class'], axis=1)

# X_test = X_test[X_test.Class == 0]
y_test = X_test['Class']
X_test = pd.DataFrame(X_test)
X_test = X_test.drop(['Class'], axis=1)

def normalize(label):
    str = StandardScaler()
    str.fit(X_train[label].values.reshape(-1, 1))
    X_train[label] = str.transform(X_train[label].values.reshape(-1, 1))
    X_test[label] = str.transform(X_test[label].values.reshape(-1, 1))

def normalize1(label):
    str = MinMaxScaler()
    str.fit(X_train[label].values.reshape(-1, 1))
    X_train[label] = str.transform(X_train[label].values.reshape(-1, 1))
    X_test[label] = str.transform(X_test[label].values.reshape(-1, 1))

A = ['RPM1', 'RPM2', 'RPM3', 'RPM4', 'RPM5', 'RPM6', 'P', 'Q', 'R', 'Phi', 'Theta', 'Psi']

for i in A:
    normalize(i)

X_train = X_train.values
X_test = X_test.values

# %%
input_dim = 12
latent_dim = 4

class Autoencoder(Model):
    def __init__(self, latent_dim):
        super(Autoencoder, self).__init__()
        self.latent_dim = latent_dim
        self.encoder = Sequential([
            layers.Dense(8, activation='sigmoid',
                        activity_regularizer=regularizers.l2(10e-3)),
            # layers.Dense(8, activation='sigmoid'),
            layers.Dense(latent_dim, activation='relu'),
        ])
        self.decoder = Sequential([
            layers.Dense(8, activation='relu'),
            layers.Dense(input_dim, activation='tanh'),
        ])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
autoencoder = Autoencoder(latent_dim)
autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())
callback = EarlyStopping(monitor='val_loss', patience=3)
checkpointer = ModelCheckpoint(filepath="AE",
                               monitor='val_loss',
                               verbose=0,
                               save_best_only=True)

tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

batch_size = 4
nb_epochs = 100
history = autoencoder.fit(X_train, X_train,
                        epochs=nb_epochs,
                        batch_size=batch_size,
                        shuffle=True,
                        validation_split=0.4,
                        callbacks=[checkpointer, tensorboard]).history

autoencoder.summary()
# Out:
# Epoch 1/100
# 2573/2590 [============================>.] - ETA: 0s - loss: 0.6655INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.6649 - val_loss: 0.5354
# Epoch 2/100
# 2579/2590 [============================>.] - ETA: 0s - loss: 0.4636INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.4636 - val_loss: 0.4136
# Epoch 3/100
# 2558/2590 [============================>.] - ETA: 0s - loss: 0.4064INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.4056 - val_loss: 0.3996
# Epoch 4/100
# 2543/2590 [============================>.] - ETA: 0s - loss: 0.3938INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3939 - val_loss: 0.3900
# Epoch 5/100
# 2578/2590 [============================>.] - ETA: 0s - loss: 0.3796INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3798 - val_loss: 0.3766
# Epoch 6/100
# 2551/2590 [============================>.] - ETA: 0s - loss: 0.3667INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3668 - val_loss: 0.3654
# Epoch 7/100
# 2565/2590 [============================>.] - ETA: 0s - loss: 0.3594INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3595 - val_loss: 0.3578
# Epoch 8/100
# 2582/2590 [============================>.] - ETA: 0s - loss: 0.3562INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3563 - val_loss: 0.3549
# Epoch 9/100
# 2544/2590 [============================>.] - ETA: 0s - loss: 0.3542INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3546 - val_loss: 0.3525
# Epoch 10/100
# 2576/2590 [============================>.] - ETA: 0s - loss: 0.3535INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3532 - val_loss: 0.3523
# Epoch 11/100
# 2550/2590 [============================>.] - ETA: 0s - loss: 0.3516INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 6s 2ms/step - loss: 0.3521 - val_loss: 0.3511
# Epoch 12/100
# 2536/2590 [============================>.] - ETA: 0s - loss: 0.3516INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3513 - val_loss: 0.3509
# Epoch 13/100
# 2558/2590 [============================>.] - ETA: 0s - loss: 0.3499INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3506 - val_loss: 0.3490
# Epoch 14/100
# 2581/2590 [============================>.] - ETA: 0s - loss: 0.3496INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3497 - val_loss: 0.3482
# Epoch 15/100
# 2555/2590 [============================>.] - ETA: 0s - loss: 0.3488INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3490 - val_loss: 0.3481
# Epoch 16/100
# 2576/2590 [============================>.] - ETA: 0s - loss: 0.3480INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3482 - val_loss: 0.3472
# Epoch 17/100
# 2535/2590 [============================>.] - ETA: 0s - loss: 0.3465INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3471 - val_loss: 0.3466
# Epoch 18/100
# 2559/2590 [============================>.] - ETA: 0s - loss: 0.3465INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3456 - val_loss: 0.3434
# Epoch 19/100
# 2586/2590 [============================>.] - ETA: 0s - loss: 0.3441INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3439 - val_loss: 0.3421
# Epoch 20/100
# 2536/2590 [============================>.] - ETA: 0s - loss: 0.3418INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3423 - val_loss: 0.3399
# Epoch 21/100
# 2569/2590 [============================>.] - ETA: 0s - loss: 0.3406INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3406 - val_loss: 0.3393
# Epoch 22/100
# 2561/2590 [============================>.] - ETA: 0s - loss: 0.3389INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3391 - val_loss: 0.3363
# Epoch 23/100
# 2561/2590 [============================>.] - ETA: 0s - loss: 0.3373INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3381 - val_loss: 0.3358
# Epoch 24/100
# 2573/2590 [============================>.] - ETA: 0s - loss: 0.3367INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3367 - val_loss: 0.3343
# Epoch 25/100
# 2543/2590 [============================>.] - ETA: 0s - loss: 0.3357INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3356 - val_loss: 0.3337
# Epoch 26/100
# 2583/2590 [============================>.] - ETA: 0s - loss: 0.3348INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3347 - val_loss: 0.3320
# Epoch 27/100
# 2548/2590 [============================>.] - ETA: 0s - loss: 0.3335INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3337 - val_loss: 0.3314
# Epoch 28/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3327 - val_loss: 0.3322
# Epoch 29/100
# 2569/2590 [============================>.] - ETA: 0s - loss: 0.3323INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3322 - val_loss: 0.3296
# Epoch 30/100
# 2567/2590 [============================>.] - ETA: 0s - loss: 0.3316INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3315 - val_loss: 0.3294
# Epoch 31/100
# 2584/2590 [============================>.] - ETA: 0s - loss: 0.3311INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3308 - val_loss: 0.3290
# Epoch 32/100
# 2574/2590 [============================>.] - ETA: 0s - loss: 0.3307INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3302 - val_loss: 0.3275
# Epoch 33/100
# 2553/2590 [============================>.] - ETA: 0s - loss: 0.3298INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3293 - val_loss: 0.3275
# Epoch 34/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3285 - val_loss: 0.3277
# Epoch 35/100
# 2551/2590 [============================>.] - ETA: 0s - loss: 0.3276INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3280 - val_loss: 0.3273
# Epoch 36/100
# 2553/2590 [============================>.] - ETA: 0s - loss: 0.3278INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3274 - val_loss: 0.3252
# Epoch 37/100
# 2567/2590 [============================>.] - ETA: 0s - loss: 0.3270INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3269 - val_loss: 0.3239
# Epoch 38/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3262 - val_loss: 0.3253
# Epoch 39/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3260 - val_loss: 0.3255
# Epoch 40/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3258 - val_loss: 0.3239
# Epoch 41/100
# 2572/2590 [============================>.] - ETA: 0s - loss: 0.3257INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3252 - val_loss: 0.3223
# Epoch 42/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3250 - val_loss: 0.3235
# Epoch 43/100
# 2578/2590 [============================>.] - ETA: 0s - loss: 0.3249INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3248 - val_loss: 0.3218
# Epoch 44/100
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3244 - val_loss: 0.3224
# Epoch 45/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3242 - val_loss: 0.3232
# Epoch 46/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3239 - val_loss: 0.3226
# Epoch 47/100
# 2574/2590 [============================>.] - ETA: 0s - loss: 0.3240INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3237 - val_loss: 0.3209
# Epoch 48/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3232 - val_loss: 0.3215
# Epoch 49/100
# 2553/2590 [============================>.] - ETA: 0s - loss: 0.3225INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3230 - val_loss: 0.3206
# Epoch 50/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3227 - val_loss: 0.3209
# Epoch 51/100
# 2543/2590 [============================>.] - ETA: 0s - loss: 0.3224INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3223 - val_loss: 0.3198
# Epoch 52/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3221 - val_loss: 0.3199
# Epoch 53/100
# 2568/2590 [============================>.] - ETA: 0s - loss: 0.3217INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3219 - val_loss: 0.3195
# Epoch 54/100
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3216 - val_loss: 0.3199
# Epoch 55/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3215 - val_loss: 0.3198
# Epoch 56/100
# 2538/2590 [============================>.] - ETA: 0s - loss: 0.3207INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3212 - val_loss: 0.3190
# Epoch 57/100
# 2554/2590 [============================>.] - ETA: 0s - loss: 0.3217INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3211 - val_loss: 0.3188
# Epoch 58/100
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3211 - val_loss: 0.3201
# Epoch 59/100
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3208 - val_loss: 0.3192
# Epoch 60/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3207 - val_loss: 0.3196
# Epoch 61/100
# 2577/2590 [============================>.] - ETA: 0s - loss: 0.3209INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3206 - val_loss: 0.3185
# Epoch 62/100
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3205 - val_loss: 0.3192
# Epoch 63/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3204 - val_loss: 0.3210
# Epoch 64/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3202 - val_loss: 0.3200
# Epoch 65/100
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3200 - val_loss: 0.3186
# Epoch 66/100
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3202 - val_loss: 0.3186
# Epoch 67/100
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3200 - val_loss: 0.3185
# Epoch 68/100
# 2561/2590 [============================>.] - ETA: 0s - loss: 0.3197INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 6s 2ms/step - loss: 0.3198 - val_loss: 0.3182
# Epoch 69/100
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3197 - val_loss: 0.3204
# Epoch 70/100
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3197 - val_loss: 0.3189
# Epoch 71/100
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3196 - val_loss: 0.3184
# Epoch 72/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3196 - val_loss: 0.3196
# Epoch 73/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3195 - val_loss: 0.3185
# Epoch 74/100
# 2580/2590 [============================>.] - ETA: 0s - loss: 0.3194INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3194 - val_loss: 0.3181
# Epoch 75/100
# 2554/2590 [============================>.] - ETA: 0s - loss: 0.3194INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3192 - val_loss: 0.3180
# Epoch 76/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3193 - val_loss: 0.3195
# Epoch 77/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3192 - val_loss: 0.3217
# Epoch 78/100
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3191 - val_loss: 0.3186
# Epoch 79/100
# 2568/2590 [============================>.] - ETA: 0s - loss: 0.3193INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 8s 3ms/step - loss: 0.3190 - val_loss: 0.3177
# Epoch 80/100
# 2590/2590 [==============================] - 6s 2ms/step - loss: 0.3188 - val_loss: 0.3181
# Epoch 81/100
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3188 - val_loss: 0.3183
# Epoch 82/100
# 2570/2590 [============================>.] - ETA: 0s - loss: 0.3184INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3185 - val_loss: 0.3174
# Epoch 83/100
# 2543/2590 [============================>.] - ETA: 0s - loss: 0.3186INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3184 - val_loss: 0.3163
# Epoch 84/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3183 - val_loss: 0.3181
# Epoch 85/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3181 - val_loss: 0.3213
# Epoch 86/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3183 - val_loss: 0.3178
# Epoch 87/100
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3181 - val_loss: 0.3196
# Epoch 88/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3181 - val_loss: 0.3170
# Epoch 89/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3179 - val_loss: 0.3172
# Epoch 90/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3179 - val_loss: 0.3168
# Epoch 91/100
# 2590/2590 [==============================] - 4s 2ms/step - loss: 0.3178 - val_loss: 0.3167
# Epoch 92/100
# 2587/2590 [============================>.] - ETA: 0s - loss: 0.3175INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3177 - val_loss: 0.3162
# Epoch 93/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3175 - val_loss: 0.3163
# Epoch 94/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3174 - val_loss: 0.3167
# Epoch 95/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3170 - val_loss: 0.3169
# Epoch 96/100
# 2590/2590 [==============================] - 4s 1ms/step - loss: 0.3170 - val_loss: 0.3164
# Epoch 97/100
# 2585/2590 [============================>.] - ETA: 0s - loss: 0.3168INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3168 - val_loss: 0.3161
# Epoch 98/100
# 2584/2590 [============================>.] - ETA: 0s - loss: 0.3163INFO:tensorflow:Assets written to: AE\assets
# 2590/2590 [==============================] - 5s 2ms/step - loss: 0.3168 - val_loss: 0.3160
# Epoch 99/100
# 2590/2590 [==============================] - 3s 1ms/step - loss: 0.3166 - val_loss: 0.3165
# Epoch 100/100
# 2590/2590 [==============================] - 3s 1ms/step - loss: 0.3163 - val_loss: 0.3163
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 4)                 140
#
#  sequential_1 (Sequential)   (None, 12)                148
#
# =================================================================
# Total params: 288
# Trainable params: 288
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.plot(range(nb_epochs), history['loss'], label='Training Loss')
plt.plot(range(nb_epochs), history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
'''
오류 분포표
- 정밀도(Precision)
: 참인데 참이라고 예측한 데이터 / 참이라고 예측한 데이터
: 정상인데 정상이라고 예측한 데이터 / 정상이라고 예측한 데이터
- 재현율(Recall)
: 참인데 참이라고 예측한 데이터 / 실제로 참인 데이터
: 정상인테 정상이라고 예측한 데이터 / 실제로 정상인 데이터
'''
predictions1 = autoencoder.predict(X_train)
predictions2 = autoencoder.predict(X_test)
mse = np.mean(np.power((X_train - predictions1), 2), axis=1)
aver_rmse = np.mean(np.sqrt(mse), axis=0)
thresholds = max(mse)
mse2 = np.mean(np.power((X_test - predictions2), 2), axis=1)

error_df = pd.DataFrame({'reconstruction_error': mse2,
                        'true_class': y_test})
# print(error_df.shape)
# error_df.describe()
error_df.reconstruction_error = error_df.reconstruction_error >= thresholds
error_df['reconstruction_error'] = error_df['reconstruction_error'].astype(int)
    
# print(error_df.shape[0])
print(error_df.reconstruction_error)
# print(error_df)
# Out:
# 610/610 [==============================] - 0s 678us/step
# 540/540 [==============================] - 0s 586us/step
# 610/610 [==============================] - 0s 568us/step
# 10873    0
# 27504    0
# 37607    1
# 31725    0
# 5140     0
#         ..
# 17557    0
# 21176    0
# 6423     0
# 15508    0
# 20785    0
# Name: reconstruction_error, Length: 19500, dtype: int32

# %%
# 정상 거래 데이터들의 재구성 오류 분포
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)
ax.set_title('normal reconstruction error distribution')
ax.set_xlabel('reconstruction error')
ax.set_ylabel('data')
# Out:
# Text(0, 0.5, 'data')

# %%
# 이상 거래 데이터들의 재구성 오류 분포
fig = plt.figure()
ax = fig.add_subplot(111)
Abnormal_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(Abnormal_error_df.reconstruction_error.values, bins=10)
ax.set_title('abnormal reconstruction error distribution')
ax.set_xlabel('reconstruction error')
ax.set_ylabel('data')
plt.show();

# %%
# ROC 곡선을 통한 평가
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)
# ROC 곡선은 이진 분류기(binary classifier)의 성능을 평가하는 유용한 도구이다.
# 굉정히 불균형한 데이터셋을 가지고 있기 때문에 일반적인 경우가 아님
fpr, tpr, thresholds2 = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)
F1_score = f1_score(error_df.true_class, error_df.reconstruction_error)
print(F1_score)
# Out:
# 0.9968957871396896

# %%
predictions1 = autoencoder.predict(X_train)
mse = np.mean(np.power((X_train - predictions1), 2), axis=1)
aver_rmse = np.mean(np.sqrt(mse), axis=0)
thresholds = max(mse)

# ROC curve
plt.figure()
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
# plt.xlim([-0.001, 1])
# plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# precision-recall curve
precision, recall, th2 = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='F1 score = %0.4f'% F1_score)
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(loc='lower left')
plt.show();

# Generate confusion matrix
# y_pred = [1 if e > thresholds else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(y_test, error_df.reconstruction_error)
LABELS = ["Normal", "Abnormal"]
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, 
                        annot=True, fmt="d", annot_kws={'size': 20}, cmap="YlGnBu", 
                        vmin=0, vmax=4000);
plt.title("Confusion matrix")
plt.xlabel('Predicted class')
plt.ylabel('True class')
plt.show()
# Out:
# 540/540 [==============================] - 0s 855us/step

# %%
# #
# predictions = autoencoder.predict(X_train)
# square_error1 = np.power((X_train - predictions), 2)
# groups = error_df.groupby('true_class')
# fig, ax = plt.subplots()

# for name, group in groups:
#     ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
#             label= "Abnormal" if name == 1 else "Normal")
# ax.hlines(thresholds, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
# ax.legend()
# plt.title("Reconstruction error for different classes")
# plt.ylabel("Reconstruction error")
# plt.xlabel("Data point index")
# plt.show();

# fig, ax = plt.subplots()

# for name, group in groups:
#     ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
#             label= "Abnormal" if name == 1 else "Normal")
# ax.hlines(thresholds, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
# ax.legend()
# plt.title("Reconstruction error for different classes")
# plt.ylabel("Reconstruction error")
# plt.xlabel("Data point index")
# plt.ylim([0, 10])
# plt.show();

# y_pred = [1 if e > thresholds else 0 for e in error_df.reconstruction_error.values]
# conf_matrix = confusion_matrix(error_df.true_class, y_pred)
# plt.figure(figsize=(12, 12))
# sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
# plt.title("Confusion matrix")
# plt.ylabel('True class')
# plt.xlabel('Predicted class')
# plt.show()
