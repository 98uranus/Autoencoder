# %%
from sklearn.mixture import GaussianMixture
from sklearn.metrics import precision_score, recall_score, f1_score, auc
from sklearn.model_selection import train_test_split
from keras import layers, Model
from keras.models import Sequential, load_model
import numpy as np
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping
from keras import regularizers, layers, losses
from keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn.metrics import precision_recall_curve, confusion_matrix, roc_curve, PrecisionRecallDisplay
from keras.utils import plot_model
import pandas as pd
import seaborn as sns
import joblib

# %%
# Generate some sample data for the autoencoder
# x_train = np.random.rand(1000, 12)
# x_test = np.random.rand(100, 12)

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

RANDOM_SEED = 42

df = pd.read_csv("Autoencoder_wind.csv")  
print(df.shape)

LABELS = ["Normal", "Abnormal"]

count_classes =pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Data Class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Data")
plt.show();

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from cmath import pi

data = df.drop(['Time'], axis=1)
y_true = df['Class']

r2d = 180/pi

data['P'] = r2d * data['P']
data['Q'] = r2d * data['Q']
data['R'] = r2d * data['R']
data['Phi'] = r2d * data['Phi']
data['Theta'] = r2d * data['Theta']
data['Psi'] = r2d * data['Psi']
# Out:
# (40000, 14)

# %%
X_train, X_test = train_test_split(data, test_size=0.5, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
y_train = X_train['Class']
X_train = pd.DataFrame(X_train)
X_train = X_train.drop(['Class'], axis=1)

# X_test = X_test[X_test.Class == 0]
y_test = X_test['Class']
X_test = pd.DataFrame(X_test)
X_test = X_test.drop(['Class'], axis=1)

def normalize(label):
    str = StandardScaler()
    str.fit(X_train[label].values.reshape(-1, 1))
    X_train[label] = str.transform(X_train[label].values.reshape(-1, 1))
    X_test[label] = str.transform(X_test[label].values.reshape(-1, 1))

def normalize1(label):
    str = MinMaxScaler()
    str.fit(X_train[label].values.reshape(-1, 1))
    X_train[label] = str.transform(X_train[label].values.reshape(-1, 1))
    X_test[label] = str.transform(X_test[label].values.reshape(-1, 1))

A = ['RPM1', 'RPM2', 'RPM3', 'RPM4', 'RPM5', 'RPM6', 'P', 'Q', 'R', 'Phi', 'Theta', 'Psi']

for i in A:
    normalize(i)

X_train = X_train.values
X_test = X_test.values

print(X_train[0])
print(X_test[0])
# Out:
# [-1.40989753 -0.52866957  0.67525685  1.40989753  0.52866957 -0.67525685
#  -0.48712107 -0.27342236  0.0223563   0.27396673 -0.03151478 -1.49741605]
# [ 1.36652432  0.19456036 -0.86998553 -1.36652432 -0.19456037  0.86998553
#   0.16060353 -3.4816681   0.01589764 -1.24839542  0.47112882 -1.15935931]

# %%
input_dim = 12
latent_dim = 4

class Autoencoder(Model):
    def __init__(self, latent_dim):
        super(Autoencoder, self).__init__()
        self.latent_dim = latent_dim
        self.encoder = Sequential([
            # layers.Dense(8, activation='sigmoid',
            #             activity_regularizer=regularizers.l2(10e-3)),
            layers.Dense(8, activation='relu'),
            layers.Dense(latent_dim, activation='relu'),
        ])
        self.decoder = Sequential([
            layers.Dense(8, activation='relu'),
            layers.Dense(input_dim, activation='relu'),
        ])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
autoencoder = Autoencoder(latent_dim)
autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())
callback = EarlyStopping(monitor='val_loss', patience=3)
checkpointer = ModelCheckpoint(filepath="AE_h8_l4",
                               monitor='val_loss',
                               verbose=0,
                               save_best_only=True)

tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

batch_size = 4
nb_epochs = 100
history = autoencoder.fit(X_train, X_train,
                        epochs=nb_epochs,
                        batch_size=batch_size,
                        shuffle=True,
                        validation_split=0.4,
                        callbacks=[checkpointer, tensorboard]).history

autoencoder.summary()
# Out:
# Epoch 1/100
# 2661/2665 [============================>.] - ETA: 0s - loss: 0.1385INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 5s 2ms/step - loss: 0.1385 - val_loss: 0.1263
# Epoch 2/100
# 2665/2665 [==============================] - ETA: 0s - loss: 0.0957INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.0957 - val_loss: 0.0930
# Epoch 3/100
# 2605/2665 [============================>.] - ETA: 0s - loss: 0.0921INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 5s 2ms/step - loss: 0.0920 - val_loss: 0.0924
# Epoch 4/100
# 2652/2665 [============================>.] - ETA: 0s - loss: 0.0915INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0915 - val_loss: 0.0919
# Epoch 5/100
# 2612/2665 [============================>.] - ETA: 0s - loss: 0.0906INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0906 - val_loss: 0.0908
# Epoch 6/100
# 2661/2665 [============================>.] - ETA: 0s - loss: 0.0767INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0766 - val_loss: 0.0664
# Epoch 7/100
# 2661/2665 [============================>.] - ETA: 0s - loss: 0.0658INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0658 - val_loss: 0.0657
# Epoch 8/100
# 2663/2665 [============================>.] - ETA: 0s - loss: 0.0653INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0653 - val_loss: 0.0653
# Epoch 9/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0651 - val_loss: 0.0653
# Epoch 10/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0650 - val_loss: 0.0653
# Epoch 11/100
# 2663/2665 [============================>.] - ETA: 0s - loss: 0.0649INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0649 - val_loss: 0.0651
# Epoch 12/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0649 - val_loss: 0.0652
# Epoch 13/100
# 2655/2665 [============================>.] - ETA: 0s - loss: 0.0649INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0649 - val_loss: 0.0650
# Epoch 14/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0648 - val_loss: 0.0653
# Epoch 15/100
# 2657/2665 [============================>.] - ETA: 0s - loss: 0.0648INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0648 - val_loss: 0.0650
# Epoch 16/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0648 - val_loss: 0.0651
# Epoch 17/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0648 - val_loss: 0.0651
# Epoch 18/100
# 2616/2665 [============================>.] - ETA: 0s - loss: 0.0648INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0648 - val_loss: 0.0649
# Epoch 19/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0648 - val_loss: 0.0650
# Epoch 20/100
# 2633/2665 [============================>.] - ETA: 0s - loss: 0.0648INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0648 - val_loss: 0.0649
# Epoch 21/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0648 - val_loss: 0.0649
# Epoch 22/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0648 - val_loss: 0.0650
# Epoch 23/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0648 - val_loss: 0.0649
# Epoch 24/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0648 - val_loss: 0.0649
# Epoch 25/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0648 - val_loss: 0.0652
# Epoch 26/100
# 2662/2665 [============================>.] - ETA: 0s - loss: 0.0408INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0408 - val_loss: 0.0340
# Epoch 27/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0341 - val_loss: 0.0341
# Epoch 28/100
# 2640/2665 [============================>.] - ETA: 0s - loss: 0.0341INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0341 - val_loss: 0.0338
# Epoch 29/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0341 - val_loss: 0.0339
# Epoch 30/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0341 - val_loss: 0.0339
# Epoch 31/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0341 - val_loss: 0.0341
# Epoch 32/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0341 - val_loss: 0.0340
# Epoch 33/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0341 - val_loss: 0.0339
# Epoch 34/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0340 - val_loss: 0.0338
# Epoch 35/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0341 - val_loss: 0.0339
# Epoch 36/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0341 - val_loss: 0.0342
# Epoch 37/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0341 - val_loss: 0.0342
# Epoch 38/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0340 - val_loss: 0.0340
# Epoch 39/100
# 2645/2665 [============================>.] - ETA: 0s - loss: 0.0341INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0340 - val_loss: 0.0338
# Epoch 40/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0340 - val_loss: 0.0347
# Epoch 41/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0340 - val_loss: 0.0340
# Epoch 42/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0340 - val_loss: 0.0340
# Epoch 43/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0340 - val_loss: 0.0341
# Epoch 44/100
# 2629/2665 [============================>.] - ETA: 0s - loss: 0.0341INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0340 - val_loss: 0.0338
# Epoch 45/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0340 - val_loss: 0.0340
# Epoch 46/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0340 - val_loss: 0.0340
# Epoch 47/100
# 2643/2665 [============================>.] - ETA: 0s - loss: 0.0340INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0340 - val_loss: 0.0338
# Epoch 48/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0340 - val_loss: 0.0338
# Epoch 49/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0340 - val_loss: 0.0338
# Epoch 50/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0340 - val_loss: 0.0339
# Epoch 51/100
# 2650/2665 [============================>.] - ETA: 0s - loss: 0.0340INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0340 - val_loss: 0.0337
# Epoch 52/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0340 - val_loss: 0.0337
# Epoch 53/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0339 - val_loss: 0.0340
# Epoch 54/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0339 - val_loss: 0.0339
# Epoch 55/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0339 - val_loss: 0.0340
# Epoch 56/100
# 2656/2665 [============================>.] - ETA: 0s - loss: 0.0339INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0339 - val_loss: 0.0337
# Epoch 57/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0339 - val_loss: 0.0337
# Epoch 58/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0338 - val_loss: 0.0339
# Epoch 59/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0338 - val_loss: 0.0338
# Epoch 60/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0338 - val_loss: 0.0340
# Epoch 61/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0338 - val_loss: 0.0338
# Epoch 62/100
# 2635/2665 [============================>.] - ETA: 0s - loss: 0.0337INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0337 - val_loss: 0.0336
# Epoch 63/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0337 - val_loss: 0.0336
# Epoch 64/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0337 - val_loss: 0.0336
# Epoch 65/100
# 2645/2665 [============================>.] - ETA: 0s - loss: 0.0336INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0336 - val_loss: 0.0335
# Epoch 66/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0336 - val_loss: 0.0336
# Epoch 67/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0335 - val_loss: 0.0336
# Epoch 68/100
# 2619/2665 [============================>.] - ETA: 0s - loss: 0.0335INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0335 - val_loss: 0.0333
# Epoch 69/100
# 2639/2665 [============================>.] - ETA: 0s - loss: 0.0335INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0335 - val_loss: 0.0333
# Epoch 70/100
# 2607/2665 [============================>.] - ETA: 0s - loss: 0.0333INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0333 - val_loss: 0.0328
# Epoch 71/100
# 2640/2665 [============================>.] - ETA: 0s - loss: 0.0327INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0327 - val_loss: 0.0326
# Epoch 72/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0323 - val_loss: 0.0328
# Epoch 73/100
# 2637/2665 [============================>.] - ETA: 0s - loss: 0.0321INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0321 - val_loss: 0.0321
# Epoch 74/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0318 - val_loss: 0.0321
# Epoch 75/100
# 2622/2665 [============================>.] - ETA: 0s - loss: 0.0317INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0317 - val_loss: 0.0316
# Epoch 76/100
# 2663/2665 [============================>.] - ETA: 0s - loss: 0.0315INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0315 - val_loss: 0.0314
# Epoch 77/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0314 - val_loss: 0.0317
# Epoch 78/100
# 2653/2665 [============================>.] - ETA: 0s - loss: 0.0312INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0312 - val_loss: 0.0312
# Epoch 79/100
# 2652/2665 [============================>.] - ETA: 0s - loss: 0.0311INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0311 - val_loss: 0.0310
# Epoch 80/100
# 2607/2665 [============================>.] - ETA: 0s - loss: 0.0309INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0309 - val_loss: 0.0309
# Epoch 81/100
# 2657/2665 [============================>.] - ETA: 0s - loss: 0.0307INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0307 - val_loss: 0.0306
# Epoch 82/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0304 - val_loss: 0.0308
# Epoch 83/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0302 - val_loss: 0.0307
# Epoch 84/100
# 2606/2665 [============================>.] - ETA: 0s - loss: 0.0301INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0301 - val_loss: 0.0301
# Epoch 85/100
# 2660/2665 [============================>.] - ETA: 0s - loss: 0.0297INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0297 - val_loss: 0.0298
# Epoch 86/100
# 2640/2665 [============================>.] - ETA: 0s - loss: 0.0293INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0293 - val_loss: 0.0291
# Epoch 87/100
# 2649/2665 [============================>.] - ETA: 0s - loss: 0.0291INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0291 - val_loss: 0.0290
# Epoch 88/100
# 2611/2665 [============================>.] - ETA: 0s - loss: 0.0289INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0289 - val_loss: 0.0289
# Epoch 89/100
# 2660/2665 [============================>.] - ETA: 0s - loss: 0.0288INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0288 - val_loss: 0.0288
# Epoch 90/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0288 - val_loss: 0.0288
# Epoch 91/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0287 - val_loss: 0.0290
# Epoch 92/100
# 2609/2665 [============================>.] - ETA: 0s - loss: 0.0287INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0287 - val_loss: 0.0286
# Epoch 93/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0286 - val_loss: 0.0291
# Epoch 94/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0286 - val_loss: 0.0287
# Epoch 95/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0285 - val_loss: 0.0287
# Epoch 96/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0285 - val_loss: 0.0288
# Epoch 97/100
# 2665/2665 [==============================] - 3s 1ms/step - loss: 0.0285 - val_loss: 0.0287
# Epoch 98/100
# 2612/2665 [============================>.] - ETA: 0s - loss: 0.0285INFO:tensorflow:Assets written to: AE_h8_l4\assets
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0285 - val_loss: 0.0284
# Epoch 99/100
# 2665/2665 [==============================] - 4s 1ms/step - loss: 0.0284 - val_loss: 0.0287
# Epoch 100/100
# 2665/2665 [==============================] - 4s 2ms/step - loss: 0.0284 - val_loss: 0.0287
# Model: "autoencoder_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_4 (Sequential)   (None, 4)                 140
#
#  sequential_5 (Sequential)   (None, 12)                148
#
# =================================================================
# Total params: 288
# Trainable params: 288
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.plot(range(nb_epochs), history['loss'], label='Training Loss')
plt.plot(range(nb_epochs), history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
'''
오류 분포표
- 정밀도(Precision)
: 참인데 참이라고 예측한 데이터 / 참이라고 예측한 데이터
: 정상인데 정상이라고 예측한 데이터 / 정상이라고 예측한 데이터
- 재현율(Recall)
: 참인데 참이라고 예측한 데이터 / 실제로 참인 데이터
: 정상인테 정상이라고 예측한 데이터 / 실제로 정상인 데이터
'''
predictions1 = autoencoder.predict(X_train)
predictions2 = autoencoder.predict(X_test)
mse = np.mean(np.power((X_train - predictions1), 2), axis=1)
aver_rmse = np.mean(np.sqrt(mse), axis=0)
thresholds = max(mse)
mse2 = np.mean(np.power((X_test - predictions2), 2), axis=1)

error_df = pd.DataFrame({'reconstruction_error': mse2,
                        'true_class': y_test})
# print(error_df.shape)
# error_df.describe()
error_df.reconstruction_error = error_df.reconstruction_error >= thresholds
error_df['reconstruction_error'] = error_df['reconstruction_error'].astype(int)
    
# print(error_df.shape[0])
print(error_df.reconstruction_error)
# print(error_df)
# Out:
# 556/556 [==============================] - 0s 701us/step
# 625/625 [==============================] - 0s 670us/step
# 32823    0
# 16298    0
# 28505    0
# 6689     1
# 26893    0
#         ..
# 14965    0
# 22133    0
# 5442     0
# 21456    0
# 1760     0
# Name: reconstruction_error, Length: 20000, dtype: int32

# %%
# 정상 거래 데이터들의 재구성 오류 분포
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)
ax.set_title('normal reconstruction error distribution')
ax.set_xlabel('reconstruction error')
ax.set_ylabel('data')
ax.set_xlim([0, 1])
# Out:
# (0.0, 1.0)

# %%
# 이상 거래 데이터들의 재구성 오류 분포
fig = plt.figure()
ax = fig.add_subplot(111)
Abnormal_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(Abnormal_error_df.reconstruction_error.values, bins=10)
ax.set_title('abnormal reconstruction error distribution')
ax.set_xlabel('reconstruction error')
ax.set_ylabel('data')
plt.show();

# %%
# ROC 곡선을 통한 평가
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)
# ROC 곡선은 이진 분류기(binary classifier)의 성능을 평가하는 유용한 도구이다.
# 굉정히 불균형한 데이터셋을 가지고 있기 때문에 일반적인 경우가 아님
fpr, tpr, thresholds2 = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)
F1_score = f1_score(error_df.true_class, error_df.reconstruction_error)
print(F1_score)
# Out:
# 0.995569339831635

# %%
predictions1 = autoencoder.predict(X_train)
mse = np.mean(np.power((X_train - predictions1), 2), axis=1)
aver_rmse = np.mean(np.sqrt(mse), axis=0)
thresholds = max(mse)

# ROC curve
plt.figure()
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
# plt.xlim([-0.001, 1])
# plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# precision-recall curve
precision, recall, th2 = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='F1 score = %0.4f'% F1_score)
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(loc='lower left')
plt.show();

# Generate confusion matrix
# y_pred = [1 if e > thresholds else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(y_test, error_df.reconstruction_error)
LABELS = ["Normal", "Abnormal"]
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, 
                        annot=True, fmt="d", annot_kws={'size': 20}, cmap="YlGnBu", 
                        vmin=0, vmax=4000);
plt.title("Confusion matrix")
plt.xlabel('Predicted class')
plt.ylabel('True class')
plt.show()
# Out:
# 556/556 [==============================] - 0s 792us/step

# %%
# #
# predictions = autoencoder.predict(X_train)
# square_error1 = np.power((X_train - predictions), 2)
# groups = error_df.groupby('true_class')
# fig, ax = plt.subplots()

# for name, group in groups:
#     ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
#             label= "Abnormal" if name == 1 else "Normal")
# ax.hlines(thresholds, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
# ax.legend()
# plt.title("Reconstruction error for different classes")
# plt.ylabel("Reconstruction error")
# plt.xlabel("Data point index")
# plt.show();

# fig, ax = plt.subplots()

# for name, group in groups:
#     ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
#             label= "Abnormal" if name == 1 else "Normal")
# ax.hlines(thresholds, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
# ax.legend()
# plt.title("Reconstruction error for different classes")
# plt.ylabel("Reconstruction error")
# plt.xlabel("Data point index")
# plt.ylim([0, 10])
# plt.show();

# y_pred = [1 if e > thresholds else 0 for e in error_df.reconstruction_error.values]
# conf_matrix = confusion_matrix(error_df.true_class, y_pred)
# plt.figure(figsize=(12, 12))
# sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
# plt.title("Confusion matrix")
# plt.ylabel('True class')
# plt.xlabel('Predicted class')
# plt.show()
