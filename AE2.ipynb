# %%
from sklearn.mixture import GaussianMixture
from sklearn.metrics import precision_score, recall_score, f1_score, auc
from sklearn.model_selection import train_test_split
from keras import layers, Model
from keras.models import Sequential, load_model
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import BatchNormalization
from keras.callbacks import EarlyStopping
from keras import regularizers, layers, losses
from keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn.metrics import precision_recall_curve, confusion_matrix, roc_curve, PrecisionRecallDisplay
from keras.utils import plot_model
import pandas as pd
import seaborn as sns
import joblib

# %%
# Generate some sample data for the autoencoder
# x_train = np.random.rand(1000, 12)
# x_test = np.random.rand(100, 12)

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

RANDOM_SEED = 42

df = pd.read_csv("Autoencoder1.csv")  
print(df.shape)

LABELS = ["Normal", "Abnormal"]

count_classes =pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Data Class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Data")
plt.show();

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from cmath import pi

data = df.drop(['Time'], axis=1)
y_true = df['Class']

r2d = 180/pi

data['P'] = r2d * data['P']
data['Q'] = r2d * data['Q']
data['R'] = r2d * data['R']
data['Phi'] = r2d * data['Phi']
data['Theta'] = r2d * data['Theta']
data['Psi'] = r2d * data['Psi']
# Out:
# (39000, 14)

# %%
X_train, X_test = train_test_split(data, test_size=0.5, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
y_train = X_train['Class']
X_train = pd.DataFrame(X_train)
X_train = X_train.drop(['Class'], axis=1)

# X_test = X_test[X_test.Class == 0]
y_test = X_test['Class']
X_test = pd.DataFrame(X_test)
X_test = X_test.drop(['Class'], axis=1)

X_train = X_train.values
X_test = X_test.values

# %%
input_dim = 12
latent_dim = 4

class Autoencoder(Model):
    def __init__(self, latent_dim):
        super(Autoencoder, self).__init__()
        self.latent_dim = latent_dim
        self.encoder = Sequential([
            layers.Dense(8, activation='relu'),
            layers.BatchNormalization(),
            layers.Dense(latent_dim, activation='relu'),
        ])
        self.decoder = Sequential([
            layers.Dense(8, activation='relu'),
            layers.BatchNormalization(),
            layers.Dense(input_dim, activation='relu'),
        ])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
autoencoder = Autoencoder(latent_dim)
autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())
callback = EarlyStopping(monitor='val_loss', patience=3)
checkpointer = ModelCheckpoint(filepath="AE2_h8_l4",
                               monitor='val_loss',
                               verbose=0,
                               save_best_only=True)

tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

batch_size = 12
nb_epochs = 100
history = autoencoder.fit(X_train, X_train,
                        epochs=nb_epochs,
                        batch_size=batch_size,
                        shuffle=True,
                        validation_split=0.4,
                        callbacks=[checkpointer, tensorboard]).history

autoencoder.summary()
# Out:
# Epoch 1/100
# 837/864 [============================>.] - ETA: 0s - loss: 0.1636INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 3s 3ms/step - loss: 0.1632 - val_loss: 0.1506
# Epoch 2/100
# 837/864 [============================>.] - ETA: 0s - loss: 0.1504INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.1504 - val_loss: 0.1491
# Epoch 3/100
# 843/864 [============================>.] - ETA: 0s - loss: 0.1098INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.1097 - val_loss: 0.1034
# Epoch 4/100
# 847/864 [============================>.] - ETA: 0s - loss: 0.0830INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0830 - val_loss: 0.0805
# Epoch 5/100
# 829/864 [===========================>..] - ETA: 0s - loss: 0.0805INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0805 - val_loss: 0.0801
# Epoch 6/100
# 848/864 [============================>.] - ETA: 0s - loss: 0.0802INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0802 - val_loss: 0.0798
# Epoch 7/100
# 811/864 [===========================>..] - ETA: 0s - loss: 0.0800INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0799 - val_loss: 0.0798
# Epoch 8/100
# 861/864 [============================>.] - ETA: 0s - loss: 0.0798INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0798 - val_loss: 0.0797
# Epoch 9/100
# 841/864 [============================>.] - ETA: 0s - loss: 0.0798INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0797 - val_loss: 0.0795
# Epoch 10/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0797 - val_loss: 0.0795
# Epoch 11/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0797 - val_loss: 0.0795
# Epoch 12/100
# 859/864 [============================>.] - ETA: 0s - loss: 0.0797INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0797 - val_loss: 0.0795
# Epoch 13/100
# 847/864 [============================>.] - ETA: 0s - loss: 0.0797INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0797 - val_loss: 0.0795
# Epoch 14/100
# 840/864 [============================>.] - ETA: 0s - loss: 0.0797INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0797 - val_loss: 0.0795
# Epoch 15/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0797 - val_loss: 0.0795
# Epoch 16/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0797 - val_loss: 0.0795
# Epoch 17/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0797 - val_loss: 0.0795
# Epoch 18/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0797 - val_loss: 0.0795
# Epoch 19/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0797 - val_loss: 0.0795
# Epoch 20/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0797 - val_loss: 0.0795
# Epoch 21/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0797 - val_loss: 0.0795
# Epoch 22/100
# 863/864 [============================>.] - ETA: 0s - loss: 0.0797INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0797 - val_loss: 0.0794
# Epoch 23/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0797 - val_loss: 0.0794
# Epoch 24/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0797 - val_loss: 0.0795
# Epoch 25/100
# 827/864 [===========================>..] - ETA: 0s - loss: 0.0798INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0796 - val_loss: 0.0794
# Epoch 26/100
# 815/864 [===========================>..] - ETA: 0s - loss: 0.0797INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0796 - val_loss: 0.0794
# Epoch 27/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0796 - val_loss: 0.0794
# Epoch 28/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0796 - val_loss: 0.0795
# Epoch 29/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0796 - val_loss: 0.0794
# Epoch 30/100
# 830/864 [===========================>..] - ETA: 0s - loss: 0.0796INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0796 - val_loss: 0.0794
# Epoch 31/100
# 829/864 [===========================>..] - ETA: 0s - loss: 0.0796INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 3ms/step - loss: 0.0796 - val_loss: 0.0794
# Epoch 32/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0795 - val_loss: 0.0794
# Epoch 33/100
# 836/864 [============================>.] - ETA: 0s - loss: 0.0795INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0795 - val_loss: 0.0793
# Epoch 34/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0795 - val_loss: 0.0794
# Epoch 35/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0795 - val_loss: 0.0793
# Epoch 36/100
# 824/864 [===========================>..] - ETA: 0s - loss: 0.0794INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0795 - val_loss: 0.0793
# Epoch 37/100
# 838/864 [============================>.] - ETA: 0s - loss: 0.0795INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0795 - val_loss: 0.0793
# Epoch 38/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0794 - val_loss: 0.0793
# Epoch 39/100
# 859/864 [============================>.] - ETA: 0s - loss: 0.0794INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0794 - val_loss: 0.0792
# Epoch 40/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0794 - val_loss: 0.0793
# Epoch 41/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0794 - val_loss: 0.0792
# Epoch 42/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0793 - val_loss: 0.0793
# Epoch 43/100
# 861/864 [============================>.] - ETA: 0s - loss: 0.0793INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 3s 3ms/step - loss: 0.0793 - val_loss: 0.0792
# Epoch 44/100
# 824/864 [===========================>..] - ETA: 0s - loss: 0.0793INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 3s 3ms/step - loss: 0.0793 - val_loss: 0.0791
# Epoch 45/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0793 - val_loss: 0.0791
# Epoch 46/100
# 846/864 [============================>.] - ETA: 0s - loss: 0.0793INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0792 - val_loss: 0.0791
# Epoch 47/100
# 864/864 [==============================] - ETA: 0s - loss: 0.0792INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0792 - val_loss: 0.0791
# Epoch 48/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0792 - val_loss: 0.0791
# Epoch 49/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0792 - val_loss: 0.0791
# Epoch 50/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0792 - val_loss: 0.0792
# Epoch 51/100
# 812/864 [===========================>..] - ETA: 0s - loss: 0.0791INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0792 - val_loss: 0.0791
# Epoch 52/100
# 818/864 [===========================>..] - ETA: 0s - loss: 0.0793INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0792 - val_loss: 0.0790
# Epoch 53/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0792 - val_loss: 0.0791
# Epoch 54/100
# 824/864 [===========================>..] - ETA: 0s - loss: 0.0792INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0791 - val_loss: 0.0790
# Epoch 55/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0791 - val_loss: 0.0791
# Epoch 56/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0791 - val_loss: 0.0791
# Epoch 57/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0791 - val_loss: 0.0790
# Epoch 58/100
# 840/864 [============================>.] - ETA: 0s - loss: 0.0791INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0791 - val_loss: 0.0790
# Epoch 59/100
# 819/864 [===========================>..] - ETA: 0s - loss: 0.0791INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0791 - val_loss: 0.0789
# Epoch 60/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0791 - val_loss: 0.0790
# Epoch 61/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0791 - val_loss: 0.0790
# Epoch 62/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0791 - val_loss: 0.0790
# Epoch 63/100
# 854/864 [============================>.] - ETA: 0s - loss: 0.0790INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0791 - val_loss: 0.0789
# Epoch 64/100
# 843/864 [============================>.] - ETA: 0s - loss: 0.0790INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 3ms/step - loss: 0.0790 - val_loss: 0.0789
# Epoch 65/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0790 - val_loss: 0.0790
# Epoch 66/100
# 858/864 [============================>.] - ETA: 0s - loss: 0.0791INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0790 - val_loss: 0.0789
# Epoch 67/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0790 - val_loss: 0.0789
# Epoch 68/100
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0790 - val_loss: 0.0789
# Epoch 69/100
# 853/864 [============================>.] - ETA: 0s - loss: 0.0790INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0790 - val_loss: 0.0789
# Epoch 70/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0790 - val_loss: 0.0789
# Epoch 71/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0790 - val_loss: 0.0790
# Epoch 72/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0790 - val_loss: 0.0789
# Epoch 73/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0790 - val_loss: 0.0789
# Epoch 74/100
# 840/864 [============================>.] - ETA: 0s - loss: 0.0790INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0790 - val_loss: 0.0788
# Epoch 75/100
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0790 - val_loss: 0.0789
# Epoch 76/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0790 - val_loss: 0.0789
# Epoch 77/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0790 - val_loss: 0.0789
# Epoch 78/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0789 - val_loss: 0.0789
# Epoch 79/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0790 - val_loss: 0.0789
# Epoch 80/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0789 - val_loss: 0.0789
# Epoch 81/100
# 829/864 [===========================>..] - ETA: 0s - loss: 0.0789INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0790 - val_loss: 0.0788
# Epoch 82/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0789 - val_loss: 0.0789
# Epoch 83/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0789 - val_loss: 0.0788
# Epoch 84/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0789 - val_loss: 0.0788
# Epoch 85/100
# 844/864 [============================>.] - ETA: 0s - loss: 0.0789INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0789 - val_loss: 0.0788
# Epoch 86/100
# 821/864 [===========================>..] - ETA: 0s - loss: 0.0790INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 3ms/step - loss: 0.0789 - val_loss: 0.0788
# Epoch 87/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0789 - val_loss: 0.0788
# Epoch 88/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0789 - val_loss: 0.0789
# Epoch 89/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0789 - val_loss: 0.0789
# Epoch 90/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0789 - val_loss: 0.0788
# Epoch 91/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0789 - val_loss: 0.0788
# Epoch 92/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0789 - val_loss: 0.0788
# Epoch 93/100
# 842/864 [============================>.] - ETA: 0s - loss: 0.0789INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0789 - val_loss: 0.0788
# Epoch 94/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0789 - val_loss: 0.0789
# Epoch 95/100
# 860/864 [============================>.] - ETA: 0s - loss: 0.0789INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0789 - val_loss: 0.0788
# Epoch 96/100
# 813/864 [===========================>..] - ETA: 0s - loss: 0.0790INFO:tensorflow:Assets written to: AE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0789 - val_loss: 0.0788
# Epoch 97/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0789 - val_loss: 0.0789
# Epoch 98/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0789 - val_loss: 0.0788
# Epoch 99/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0789 - val_loss: 0.0788
# Epoch 100/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0789 - val_loss: 0.0788
# Model: "autoencoder_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_8 (Sequential)   (None, 4)                 140
#
#  sequential_9 (Sequential)   (None, 12)                148
#
# =================================================================
# Total params: 288
# Trainable params: 288
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.plot(range(nb_epochs), history['loss'], label='Train Loss')
plt.plot(range(nb_epochs), history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
'''
오류 분포표
- 정밀도(Precision)
: 참인데 참이라고 예측한 데이터 / 참이라고 예측한 데이터
: 정상인데 정상이라고 예측한 데이터 / 정상이라고 예측한 데이터
- 재현율(Recall)
: 참인데 참이라고 예측한 데이터 / 실제로 참인 데이터
: 정상인테 정상이라고 예측한 데이터 / 실제로 정상인 데이터
'''
predictions1 = autoencoder.predict(X_train)
predictions2 = autoencoder.predict(X_test)
mse = np.mean(np.power((X_train - predictions1), 2), axis=1)
aver_rmse = np.mean(np.sqrt(mse), axis=0)
thresholds = max(mse)
mse2 = np.mean(np.power((X_test - predictions2), 2), axis=1)

error_df = pd.DataFrame({'reconstruction_error': mse2,
                        'true_class': y_test})
# print(error_df.shape)
# error_df.describe()
error_df.reconstruction_error = error_df.reconstruction_error >= thresholds
error_df['reconstruction_error'] = error_df['reconstruction_error'].astype(int)
    
# print(error_df.shape[0])
print(error_df.reconstruction_error)
# print(error_df)
# Out:
# 540/540 [==============================] - 0s 752us/step
# 610/610 [==============================] - 0s 766us/step
# 10873    0
# 27504    0
# 37607    1
# 31725    0
# 5140     0
#         ..
# 17557    0
# 21176    0
# 6423     0
# 15508    0
# 20785    0
# Name: reconstruction_error, Length: 19500, dtype: int32

# %%
# 정상 거래 데이터들의 재구성 오류 분포
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)
ax.set_title('normal reconstruction error distribution')
ax.set_xlabel('reconstruction error')
ax.set_ylabel('data')
ax.set_xlim([0, 1])
# Out:
# (0.0, 1.0)

# %%
# 이상 거래 데이터들의 재구성 오류 분포
fig = plt.figure()
ax = fig.add_subplot(111)
Abnormal_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(Abnormal_error_df.reconstruction_error.values, bins=10)
ax.set_title('abnormal reconstruction error distribution')
ax.set_xlabel('reconstruction error')
ax.set_ylabel('data')
plt.show();

# %%
# ROC 곡선을 통한 평가
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)
# ROC 곡선은 이진 분류기(binary classifier)의 성능을 평가하는 유용한 도구이다.
# 굉정히 불균형한 데이터셋을 가지고 있기 때문에 일반적인 경우가 아님
fpr, tpr, thresholds2 = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)
F1_score = f1_score(error_df.true_class, error_df.reconstruction_error)
print(F1_score)
# Out:
# 0.9964444444444445

# %%
predictions1 = autoencoder.predict(X_train)
mse = np.mean(np.power((X_train - predictions1), 2), axis=1)
aver_rmse = np.mean(np.sqrt(mse), axis=0)
thresholds = max(mse)

# ROC curve
plt.figure()
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
# plt.xlim([-0.001, 1])
# plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# precision-recall curve
precision, recall, th2 = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='F1 score = %0.4f'% F1_score)
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(loc='lower left')
plt.show();

# Generate confusion matrix
# y_pred = [1 if e > thresholds else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(y_test, error_df.reconstruction_error)
LABELS = ["Normal", "Abnormal"]
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, 
                        annot=True, fmt="d", annot_kws={'size': 20}, cmap="YlGnBu", 
                        vmin=0, vmax=4000);
plt.title("Confusion matrix")
plt.xlabel('Predicted class')
plt.ylabel('True class')
plt.show()
# Out:
# 540/540 [==============================] - 0s 713us/step

# %%
# #
# predictions = autoencoder.predict(X_train)
# square_error1 = np.power((X_train - predictions), 2)
# groups = error_df.groupby('true_class')
# fig, ax = plt.subplots()

# for name, group in groups:
#     ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
#             label= "Abnormal" if name == 1 else "Normal")
# ax.hlines(thresholds, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
# ax.legend()
# plt.title("Reconstruction error for different classes")
# plt.ylabel("Reconstruction error")
# plt.xlabel("Data point index")
# plt.show();

# fig, ax = plt.subplots()

# for name, group in groups:
#     ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
#             label= "Abnormal" if name == 1 else "Normal")
# ax.hlines(thresholds, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
# ax.legend()
# plt.title("Reconstruction error for different classes")
# plt.ylabel("Reconstruction error")
# plt.xlabel("Data point index")
# plt.ylim([0, 10])
# plt.show();

# y_pred = [1 if e > thresholds else 0 for e in error_df.reconstruction_error.values]
# conf_matrix = confusion_matrix(error_df.true_class, y_pred)
# plt.figure(figsize=(12, 12))
# sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
# plt.title("Confusion matrix")
# plt.ylabel('True class')
# plt.xlabel('Predicted class')
# plt.show()
