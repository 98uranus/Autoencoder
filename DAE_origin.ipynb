# %%
from sklearn.mixture import GaussianMixture
from sklearn.metrics import precision_score, recall_score, f1_score, auc
from sklearn.model_selection import train_test_split
from keras import layers, Model
from keras.models import Sequential, load_model
import numpy as np
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping
from keras import regularizers, layers, losses
from keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn.metrics import precision_recall_curve, confusion_matrix, roc_curve, PrecisionRecallDisplay
from keras.utils import plot_model
import pandas as pd
import seaborn as sns
import joblib
from pylab import rcParams

# %%
# Generate some sample data for the autoencoder
# x_train = np.random.rand(1000, 12)
# x_test = np.random.rand(100, 12)

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

# rcParams['figure.figsize'] = 14, 8

RANDOM_SEED = 42

df = pd.read_csv("Autoencoder1.csv")  
print(df.shape)

LABELS = ["Normal", "Abnormal"]

count_classes =pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Data Class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Data")
plt.show();

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from cmath import pi

data = df.drop(['Time'], axis=1)
y_true = df['Class']

r2d = 180/pi

data['P'] = r2d * data['P']
data['Q'] = r2d * data['Q']
data['R'] = r2d * data['R']
data['Phi'] = r2d * data['Phi']
data['Theta'] = r2d * data['Theta']
data['Psi'] = r2d * data['Psi']
# Out:
# (39000, 14)

# %%
X_train, X_test = train_test_split(data, test_size=0.5, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
y_train = X_train['Class']
X_train = pd.DataFrame(X_train)
X_train = X_train.drop(['Class'], axis=1)

# X_test = X_test[X_test.Class == 0]
y_test = X_test['Class']
X_test = pd.DataFrame(X_test)
X_test = X_test.drop(['Class'], axis=1)

def MinmaxNorm(data1, data2, label):
    for i in label:
        a = data1[i]
        b = data2[i]
        x_max = max(a)
        x_min = min(a)
        for j in list(range(a.shape[0])):
            a.iloc[j] = (a.iloc[j] - x_min) / (x_max - x_min)
        for k in list(range(b.shape[0])):
            b.iloc[k] = (b.iloc[k] - x_min) / (x_max - x_min)
    
    return data1, data2

A = ['RPM1', 'RPM2', 'RPM3', 'RPM4', 'RPM5', 'RPM6', 'P', 'Q', 'R', 'Phi', 'Theta', 'Psi']

X_train, X_test = MinmaxNorm(X_train, X_test, A)

# Add noise 
noise = 0.5
X_train_noisy = X_train + noise * np.random.normal(loc=0.0, scale=1.0, size=X_train.shape)
X_test_noisy = X_test + noise * np.random.normal(loc=0.0, scale=1.0, size=X_test.shape)

X_train = X_train.values
X_test = X_test.values

X_train_noisy = X_train_noisy.values
X_test_noisy = X_test_noisy.values

# %%
input_dim = 12
latent_dim = 4

class Autoencoder(Model):
    def __init__(self, latent_dim):
        super(Autoencoder, self).__init__()
        self.latent_dim = latent_dim
        self.encoder = Sequential([
            # layers.Dense(8, activation='relu',
            #             activity_regularizer=regularizers.l2(10e-3)),
            layers.Dense(latent_dim, activation='relu'),
        ])
        self.decoder = Sequential([
            layers.Dense(input_dim, activation='relu'),
        ])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
autoencoder = Autoencoder(latent_dim)
autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())
callback = EarlyStopping(monitor='val_loss', patience=3)
checkpointer = ModelCheckpoint(filepath="DAE2_h8_l4",
                               monitor='val_loss',
                               verbose=0,
                               save_best_only=True)

tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

batch_size = 12
nb_epochs = 100
history = autoencoder.fit(X_train_noisy, X_train,
                        epochs=nb_epochs,
                        batch_size=batch_size,
                        shuffle=True,
                        validation_split=0.4,
                        callbacks=[checkpointer, tensorboard]).history

autoencoder.summary()
# Out:
# Epoch 1/100
# 853/864 [============================>.] - ETA: 0s - loss: 0.1459INFO:tensorflow:Assets written to: DAE2_h8_l4\assets
# 864/864 [==============================] - 3s 3ms/step - loss: 0.1456 - val_loss: 0.1273
# Epoch 2/100
# 855/864 [============================>.] - ETA: 0s - loss: 0.1261INFO:tensorflow:Assets written to: DAE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.1260 - val_loss: 0.1238
# Epoch 3/100
# 845/864 [============================>.] - ETA: 0s - loss: 0.1235INFO:tensorflow:Assets written to: DAE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.1235 - val_loss: 0.1227
# Epoch 4/100
# 863/864 [============================>.] - ETA: 0s - loss: 0.1032INFO:tensorflow:Assets written to: DAE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.1032 - val_loss: 0.0973
# Epoch 5/100
# 846/864 [============================>.] - ETA: 0s - loss: 0.0974INFO:tensorflow:Assets written to: DAE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0975 - val_loss: 0.0969
# Epoch 6/100
# 800/864 [==========================>...] - ETA: 0s - loss: 0.0971INFO:tensorflow:Assets written to: DAE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0971 - val_loss: 0.0964
# Epoch 7/100
# 852/864 [============================>.] - ETA: 0s - loss: 0.0968INFO:tensorflow:Assets written to: DAE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0967 - val_loss: 0.0961
# Epoch 8/100
# 815/864 [===========================>..] - ETA: 0s - loss: 0.0967INFO:tensorflow:Assets written to: DAE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0966 - val_loss: 0.0959
# Epoch 9/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0964 - val_loss: 0.0961
# Epoch 10/100
# 857/864 [============================>.] - ETA: 0s - loss: 0.0965INFO:tensorflow:Assets written to: DAE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0964 - val_loss: 0.0959
# Epoch 11/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0964 - val_loss: 0.0960
# Epoch 12/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0964 - val_loss: 0.0963
# Epoch 13/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0964 - val_loss: 0.0959
# Epoch 14/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0964 - val_loss: 0.0959
# Epoch 15/100
# 846/864 [============================>.] - ETA: 0s - loss: 0.0964INFO:tensorflow:Assets written to: DAE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0964 - val_loss: 0.0958
# Epoch 16/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0964 - val_loss: 0.0958
# Epoch 17/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0964 - val_loss: 0.0958
# Epoch 18/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0964 - val_loss: 0.0959
# Epoch 19/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0964 - val_loss: 0.0958
# Epoch 20/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0964 - val_loss: 0.0964
# Epoch 21/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0964 - val_loss: 0.0960
# Epoch 22/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0964 - val_loss: 0.0958
# Epoch 23/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0964 - val_loss: 0.0958
# Epoch 24/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0964 - val_loss: 0.0961
# Epoch 25/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 26/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0964 - val_loss: 0.0958
# Epoch 27/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0964 - val_loss: 0.0959
# Epoch 28/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 29/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0959
# Epoch 30/100
# 833/864 [===========================>..] - ETA: 0s - loss: 0.0964INFO:tensorflow:Assets written to: DAE2_h8_l4\assets
# 864/864 [==============================] - 2s 3ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 31/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0964 - val_loss: 0.0958
# Epoch 32/100
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0963 - val_loss: 0.0959
# Epoch 33/100
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0964 - val_loss: 0.0959
# Epoch 34/100
# 862/864 [============================>.] - ETA: 0s - loss: 0.0963INFO:tensorflow:Assets written to: DAE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 35/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0961
# Epoch 36/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 37/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 38/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0959
# Epoch 39/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 40/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 41/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0960
# Epoch 42/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 43/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 44/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 45/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 46/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0959
# Epoch 47/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0963 - val_loss: 0.0959
# Epoch 48/100
# 814/864 [===========================>..] - ETA: 0s - loss: 0.0962INFO:tensorflow:Assets written to: DAE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 49/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 50/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 51/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 52/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 53/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 54/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 55/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0959
# Epoch 56/100
# 798/864 [==========================>...] - ETA: 0s - loss: 0.0963INFO:tensorflow:Assets written to: DAE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 57/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0959
# Epoch 58/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 59/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0959
# Epoch 60/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 61/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0963 - val_loss: 0.0959
# Epoch 62/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 63/100
# 807/864 [===========================>..] - ETA: 0s - loss: 0.0964INFO:tensorflow:Assets written to: DAE2_h8_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 64/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0959
# Epoch 65/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 66/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 67/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0959
# Epoch 68/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 69/100
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 70/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 71/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 72/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 73/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 74/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 75/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 76/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 77/100
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 78/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0962 - val_loss: 0.0957
# Epoch 79/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 80/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 81/100
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0963 - val_loss: 0.0959
# Epoch 82/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 83/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 84/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 85/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0962 - val_loss: 0.0958
# Epoch 86/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 87/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0962 - val_loss: 0.0957
# Epoch 88/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 89/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0962 - val_loss: 0.0957
# Epoch 90/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 91/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0959
# Epoch 92/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 93/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0962 - val_loss: 0.0958
# Epoch 94/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0962 - val_loss: 0.0958
# Epoch 95/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 96/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 97/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0959
# Epoch 98/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0957
# Epoch 99/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0962 - val_loss: 0.0958
# Epoch 100/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0963 - val_loss: 0.0959
# Model: "autoencoder_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_2 (Sequential)   (None, 4)                 140
#
#  sequential_3 (Sequential)   (None, 12)                148
#
# =================================================================
# Total params: 288
# Trainable params: 288
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 평가하기
plt.figure()
plt.plot(range(nb_epochs), history['loss'])
plt.plot(range(nb_epochs), history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train Loss', 'Validation Loss'], loc='upper right');
# plt.ylim([0, 1])
plt.show()

# %%
'''
오류 분포표
- 정밀도(Precision)
: 참인데 참이라고 예측한 데이터 / 참이라고 예측한 데이터
: 정상인데 정상이라고 예측한 데이터 / 정상이라고 예측한 데이터
- 재현율(Recall)
: 참인데 참이라고 예측한 데이터 / 실제로 참인 데이터
: 정상인테 정상이라고 예측한 데이터 / 실제로 정상인 데이터
'''
predictions1 = autoencoder.predict(X_train)
predictions2 = autoencoder.predict(X_test)
mse = np.mean(np.power((X_train - predictions1), 2), axis=1)
aver_rmse = np.mean(np.sqrt(mse), axis=0)
# thresholds = aver_rmse
thresholds = max(mse)
mse2 = np.mean(np.power((X_test - predictions2), 2), axis=1)

error_df = pd.DataFrame({'reconstruction_error': mse2,
                        'true_class': y_test})
# print(error_df.shape)
# error_df.describe()
error_df.reconstruction_error = error_df.reconstruction_error >= thresholds
error_df['reconstruction_error'] = error_df['reconstruction_error'].astype(int)
    
# print(error_df.shape[0])
print(error_df.reconstruction_error)
# print(error_df)
# Out:
# 540/540 [==============================] - 0s 544us/step
# 610/610 [==============================] - 0s 573us/step
# 10873    0
# 27504    0
# 37607    1
# 31725    0
# 5140     0
#         ..
# 17557    0
# 21176    0
# 6423     0
# 15508    0
# 20785    0
# Name: reconstruction_error, Length: 19500, dtype: int32

# %%
# 정상 거래 데이터들의 재구성 오류 분포
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)
ax.set_title('normal reconstruction error distribution')
ax.set_xlabel('reconstruction error')
ax.set_ylabel('data')
ax.set_xlim([0, 1])
# Out:
# (0.0, 1.0)

# %%
# 이상 거래 데이터들의 재구성 오류 분포
fig = plt.figure()
ax = fig.add_subplot(111)
Abnormal_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(Abnormal_error_df.reconstruction_error.values, bins=10)
ax.set_title('abnormal reconstruction error distribution')
ax.set_xlabel('reconstruction error')
ax.set_ylabel('data')
plt.show();

# %%
# ROC 곡선을 통한 평가
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)
# ROC 곡선은 이진 분류기(binary classifier)의 성능을 평가하는 유용한 도구이다.
# 굉정히 불균형한 데이터셋을 가지고 있기 때문에 일반적인 경우가 아님
fpr, tpr, thresholds2 = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)
F1_score = f1_score(error_df.true_class, error_df.reconstruction_error)
print(F1_score)
# Out:
# 0.9971104689931095

# %%
# ROC curve
# plt.figure(figsize=(6, 6))
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
# plt.xlim([-0.001, 1])
# plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# precision-recall curve
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
# plt.figure(figsize=(6, 6))
plt.plot(recall, precision, 'b', label='F1 score = %0.4f'% F1_score)
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(loc='lower left')
plt.show();

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test, error_df.reconstruction_error)
LABELS = ["Normal", "Abnormal"]
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, 
                        annot=True, fmt="d", annot_kws={'size': 20}, cmap="YlGnBu", 
                        vmin=0, vmax=4000);
plt.title("Confusion matrix")
plt.xlabel('Predicted class')
plt.ylabel('True class')
plt.show()

# %%
# #
# predictions = autoencoder.predict(X_train)
# square_error1 = np.power((X_train - predictions), 2)
# groups = error_df.groupby('true_class')
# fig, ax = plt.subplots()

# for name, group in groups:
#     ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
#             label= "Abnormal" if name == 1 else "Normal")
# ax.hlines(thresholds, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
# ax.legend()
# plt.title("Reconstruction error for different classes")
# plt.ylabel("Reconstruction error")
# plt.xlabel("Data point index")
# plt.show();

# fig, ax = plt.subplots()

# for name, group in groups:
#     ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
#             label= "Abnormal" if name == 1 else "Normal")
# ax.hlines(thresholds, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
# ax.legend()
# plt.title("Reconstruction error for different classes")
# plt.ylabel("Reconstruction error")
# plt.xlabel("Data point index")
# plt.ylim([0, 10])
# plt.show();

# y_pred = [1 if e > thresholds else 0 for e in error_df.reconstruction_error.values]
# conf_matrix = confusion_matrix(error_df.true_class, y_pred)
# plt.figure(figsize=(12, 12))
# sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
# plt.title("Confusion matrix")
# plt.ylabel('True class')
# plt.xlabel('Predicted class')
# plt.show()
