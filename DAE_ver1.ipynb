# %%
from turtle import st
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model, Sequential
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers, layers, losses
from cmath import pi
from keras.callbacks import EarlyStopping
from keras.utils.vis_utils import plot_model
from sklearn.model_selection import train_test_split

# %%
sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8
# RANDOM_SEED와 LABELS 설정
RANDOM_SEED = 42
LABELS = ["Normal", "Abnormal"]


# train data
df = pd.read_csv("Autoencoder1.csv")
print(df.shape)

# 결측값 확인
print(df.isnull().values.any()) # False

count_classes =pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency")
plt.show();
# Out:
# (39000, 14)
# False

# %%
# Autoencoder는 항등 함수를 근사하도록 학습됨
# f_W,b(x) ~ x
# f는 신경망, W는 가중치(weight), b는 바이어스(bias)
# Autoencoder 신경망 : '입력값 x를 받아서 다시 입력값 x를 결과로 내보내는 함수'
# 특정 데이터의 압축된 표상(representation)을 학습시키고 그 구조(structure)를 찾고 싶어한다는 것이 중요함
# 이것은 모델 안에 은닉 유닛(hidden unit)의 수를 제한하는 방법을 통해 가능, 이런 종류의 autoencoder들은 미완성(undercomplete)이라고 부름

# 재구성 오류(Reconstruction error)
# L(x, x') = ||x - x'||^2

# 데이터 준비
# 시간 열은 삭제, Scikit-learn의 standardScaler를 거래액 열에 적용, StandardScaler는 평균을 제거하고 값들을 단위 분산(unit variance)에 맞게 스케일링 해줌
from sklearn.preprocessing import StandardScaler, MinMaxScaler

data = df.drop(['Time'], axis=1)

r2d = 180/pi

data['P'] = r2d * data['P']
data['Q'] = r2d * data['Q']
data['R'] = r2d * data['R']
data['Phi'] = r2d * data['Phi']
data['Theta'] = r2d * data['Theta']
data['Psi'] = r2d * data['Psi']

# %%
# X_train, X_test = train_test_split(data, test_size=0.6, random_state=RANDOM_SEED)
X_train, X_test = train_test_split(data, test_size=0.5, random_state=RANDOM_SEED)
# X_train2 = X_train 
# X_train = X_train[X_train.Class == 0]
X_train = pd.DataFrame(X_train)
X_train = X_train.drop(['Class'], axis=1)

# X_test = X_test[X_test.Class == 0]
y_test = X_test['Class']
X_test = pd.DataFrame(X_test)
X_test = X_test.drop(['Class'], axis=1)

def normalize(label):
    str = StandardScaler()
    str.fit(X_train[label].values.reshape(-1, 1))
    X_train[label] = str.transform(X_train[label].values.reshape(-1, 1))
    X_test[label] = str.transform(X_test[label].values.reshape(-1, 1))

def normalize1(label):
    str = MinMaxScaler()
    str.fit(X_train[label].values.reshape(-1, 1))
    X_train[label] = str.transform(X_train[label].values.reshape(-1, 1))
    X_test[label] = str.transform(X_test[label].values.reshape(-1, 1))

A = ['RPM1', 'RPM2', 'RPM3', 'RPM4', 'RPM5', 'RPM6', 'P', 'Q', 'R', 'Phi', 'Theta', 'Psi']

for i in A:
    normalize(i)

# Add noise 
noise = 0.5
X_train_noisy = X_train + noise * np.random.normal(loc=0.0, scale=1.0, size=X_train.shape)
X_test_noisy = X_test + noise * np.random.normal(loc=0.0, scale=1.0, size=X_test.shape)

# X_train_noisy = np.clip(X_train_noisy, -1, 1)
# X_test_noisy = np.clip(X_test_noisy, -1, 1)

# X_train = np.clip(X_train, -1, 1)
# X_test = np.clip(X_test, -1, 1)

X_train = X_train.values
X_test = X_test.values

X_train_noisy = X_train_noisy.values
X_test_noisy = X_test_noisy.values

# %%
input_dim = 12
latent_dim = input_dim/4

class Autoencoder(Model):
    def __init__(self, latent_dim):
        super(Autoencoder, self).__init__()
        self.latent_dim = latent_dim
        self.encoder = Sequential([
            layers.Dense(input_dim/2, activation='sigmoid'),
            # layers.Dense(input_dim/3, activation='relu'),
            layers.Dense(latent_dim, activation='relu')
        ])
        self.decoder = Sequential([
            # layers.Dense(input_dim/3, activation='relu'),
            layers.Dense(input_dim/2, activation='relu'),
            layers.Dense(input_dim, activation='tanh')
        ])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
callback = EarlyStopping(monitor='val_loss', patience=5)
autoencoder = Autoencoder(latent_dim)
autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())
checkpointer = ModelCheckpoint(filepath="Autoencoder_v2_mse",
                               monitor='val_loss',
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

autoencoder.summary()
batch_size = 8
nb_epochs = 500
history = autoencoder.fit(X_train_noisy, X_train,
                        epochs=nb_epochs,
                        batch_size=batch_size,
                        shuffle=True,
                        validation_data=(X_test_noisy, X_test),
                        callbacks=[checkpointer, tensorboard]).history
# Out:
# Epoch 1/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.7043 - val_loss: 0.8479
# Epoch 2/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.6027 - val_loss: 0.8363
# Epoch 3/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5971 - val_loss: 0.8331
# Epoch 4/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5945 - val_loss: 0.8290
# Epoch 5/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5859 - val_loss: 0.8135
# Epoch 6/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5726 - val_loss: 0.8069
# Epoch 7/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5701 - val_loss: 0.8063
# Epoch 8/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5687 - val_loss: 0.8051
# Epoch 9/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5683 - val_loss: 0.8057
# Epoch 10/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5677 - val_loss: 0.8088
# Epoch 11/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5677 - val_loss: 0.8049
# Epoch 12/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5672 - val_loss: 0.8035
# Epoch 13/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5670 - val_loss: 0.8038
# Epoch 14/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5668 - val_loss: 0.8028
# Epoch 15/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5660 - val_loss: 0.8029
# Epoch 16/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5655 - val_loss: 0.8023
# Epoch 17/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5653 - val_loss: 0.8016
# Epoch 18/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5648 - val_loss: 0.8012
# Epoch 19/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5643 - val_loss: 0.8008
# Epoch 20/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5641 - val_loss: 0.8003
# Epoch 21/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5638 - val_loss: 0.8002
# Epoch 22/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5633 - val_loss: 0.7983
# Epoch 23/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5631 - val_loss: 0.7989
# Epoch 24/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5623 - val_loss: 0.7967
# Epoch 25/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5620 - val_loss: 0.7967
# Epoch 26/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5622 - val_loss: 0.7957
# Epoch 27/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5610 - val_loss: 0.7959
# Epoch 28/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5610 - val_loss: 0.7958
# Epoch 29/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5613 - val_loss: 0.7943
# Epoch 30/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5602 - val_loss: 0.7949
# Epoch 31/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5607 - val_loss: 0.7939
# Epoch 32/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5601 - val_loss: 0.7968
# Epoch 33/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5600 - val_loss: 0.7937
# Epoch 34/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5599 - val_loss: 0.7936
# Epoch 35/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5605 - val_loss: 0.7944
# Epoch 36/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5596 - val_loss: 0.7943
# Epoch 37/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5594 - val_loss: 0.7946
# Epoch 38/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5600 - val_loss: 0.7940
# Epoch 39/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5592 - val_loss: 0.7942
# Epoch 40/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5593 - val_loss: 0.7941
# Epoch 41/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5594 - val_loss: 0.7953
# Epoch 42/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5597 - val_loss: 0.7939
# Epoch 43/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5592 - val_loss: 0.7943
# Epoch 44/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5592 - val_loss: 0.7936
# Epoch 45/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5595 - val_loss: 0.7937
# Epoch 46/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5591 - val_loss: 0.7934
# Epoch 47/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5590 - val_loss: 0.7935
# Epoch 48/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5596 - val_loss: 0.7946
# Epoch 49/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5594 - val_loss: 0.7939
# Epoch 50/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5590 - val_loss: 0.7937
# Epoch 51/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5590 - val_loss: 0.7940
# Epoch 52/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5591 - val_loss: 0.7936
# Epoch 53/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5599 - val_loss: 0.7936
# Epoch 54/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5590 - val_loss: 0.7943
# Epoch 55/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5591 - val_loss: 0.7934
# Epoch 56/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5590 - val_loss: 0.7935
# Epoch 57/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5592 - val_loss: 0.7938
# Epoch 58/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5589 - val_loss: 0.7939
# Epoch 59/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5592 - val_loss: 0.7935
# Epoch 60/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5594 - val_loss: 0.7930
# Epoch 61/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5591 - val_loss: 0.7932
# Epoch 62/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5586 - val_loss: 0.7942
# Epoch 63/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5589 - val_loss: 0.7947
# Epoch 64/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5590 - val_loss: 0.7937
# Epoch 65/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5589 - val_loss: 0.7941
# Epoch 66/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5590 - val_loss: 0.7932
# Epoch 67/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5589 - val_loss: 0.7927
# Epoch 68/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5588 - val_loss: 0.7930
# Epoch 69/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5589 - val_loss: 0.7938
# Epoch 70/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5590 - val_loss: 0.7934
# Epoch 71/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5587 - val_loss: 0.7928
# Epoch 72/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5587 - val_loss: 0.7948
# Epoch 73/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5589 - val_loss: 0.7944
# Epoch 74/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5587 - val_loss: 0.7930
# Epoch 75/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5588 - val_loss: 0.7934
# Epoch 76/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5588 - val_loss: 0.7946
# Epoch 77/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5587 - val_loss: 0.7932
# Epoch 78/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5586 - val_loss: 0.7935
# Epoch 79/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5588 - val_loss: 0.7933
# Epoch 80/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5589 - val_loss: 0.7926
# Epoch 81/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5587 - val_loss: 0.7926
# Epoch 82/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5588 - val_loss: 0.7928
# Epoch 83/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5585 - val_loss: 0.7939
# Epoch 84/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5590 - val_loss: 0.7942
# Epoch 85/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5588 - val_loss: 0.7937
# Epoch 86/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5590 - val_loss: 0.7935
# Epoch 87/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5587 - val_loss: 0.7942
# Epoch 88/500
# 2438/2438 [==============================] - 4s 2ms/step - loss: 0.5588 - val_loss: 0.7933
# Epoch 89/500
# 2438/2438 [==============================] - 4s 2ms/step - loss: 0.5587 - val_loss: 0.7934
# Epoch 90/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5587 - val_loss: 0.7927
# Epoch 91/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5589 - val_loss: 0.7941
# Epoch 92/500
# 2438/2438 [==============================] - 4s 2ms/step - loss: 0.5589 - val_loss: 0.7936
# Epoch 93/500
# 2438/2438 [==============================] - 4s 1ms/step - loss: 0.5588 - val_loss: 0.7931
# Epoch 94/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5587 - val_loss: 0.7934
# Epoch 95/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5587 - val_loss: 0.7935
# Epoch 96/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5586 - val_loss: 0.7933
# Epoch 97/500
# 2438/2438 [==============================] - 4s 2ms/step - loss: 0.5585 - val_loss: 0.7928
# Epoch 98/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5589 - val_loss: 0.7932
# Epoch 99/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5586 - val_loss: 0.7941
# Epoch 100/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5586 - val_loss: 0.7938
# Epoch 101/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5585 - val_loss: 0.7928
# Epoch 102/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5583 - val_loss: 0.7931
# Epoch 103/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5586 - val_loss: 0.7950
# Epoch 104/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5583 - val_loss: 0.7927
# Epoch 105/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5584 - val_loss: 0.7930
# Epoch 106/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5584 - val_loss: 0.7931
# Epoch 107/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5582 - val_loss: 0.7930
# Epoch 108/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5583 - val_loss: 0.7940
# Epoch 109/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5582 - val_loss: 0.7929
# Epoch 110/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5581 - val_loss: 0.7926
# Epoch 111/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5582 - val_loss: 0.7924
# Epoch 112/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5580 - val_loss: 0.7931
# Epoch 113/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5580 - val_loss: 0.7931
# Epoch 114/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5580 - val_loss: 0.7959
# Epoch 115/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5581 - val_loss: 0.7929
# Epoch 116/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5577 - val_loss: 0.7920
# Epoch 117/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5577 - val_loss: 0.7920
# Epoch 118/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5576 - val_loss: 0.7922
# Epoch 119/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5579 - val_loss: 0.7917
# Epoch 120/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5573 - val_loss: 0.7915
# Epoch 121/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5575 - val_loss: 0.7932
# Epoch 122/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5575 - val_loss: 0.7917
# Epoch 123/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5574 - val_loss: 0.7921
# Epoch 124/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5575 - val_loss: 0.7924
# Epoch 125/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5574 - val_loss: 0.7933
# Epoch 126/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5570 - val_loss: 0.7921
# Epoch 127/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5570 - val_loss: 0.7922
# Epoch 128/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5570 - val_loss: 0.7987
# Epoch 129/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5569 - val_loss: 0.7916
# Epoch 130/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5566 - val_loss: 0.7916
# Epoch 131/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5571 - val_loss: 0.7907
# Epoch 132/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5568 - val_loss: 0.7906
# Epoch 133/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5569 - val_loss: 0.7928
# Epoch 134/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5562 - val_loss: 0.7908
# Epoch 135/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5566 - val_loss: 0.7916
# Epoch 136/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5566 - val_loss: 0.7909
# Epoch 137/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5561 - val_loss: 0.7905
# Epoch 138/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5561 - val_loss: 0.7905
# Epoch 139/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5565 - val_loss: 0.7904
# Epoch 140/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5560 - val_loss: 0.7904
# Epoch 141/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5559 - val_loss: 0.7918
# Epoch 142/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5560 - val_loss: 0.7897
# Epoch 143/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5558 - val_loss: 0.7897
# Epoch 144/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5558 - val_loss: 0.7904
# Epoch 145/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5560 - val_loss: 0.7899
# Epoch 146/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5559 - val_loss: 0.7892
# Epoch 147/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5557 - val_loss: 0.7890
# Epoch 148/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5561 - val_loss: 0.7894
# Epoch 149/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5556 - val_loss: 0.7903
# Epoch 150/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5555 - val_loss: 0.7895
# Epoch 151/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5555 - val_loss: 0.7893
# Epoch 152/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5555 - val_loss: 0.7896
# Epoch 153/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5554 - val_loss: 0.7895
# Epoch 154/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5555 - val_loss: 0.7897
# Epoch 155/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5554 - val_loss: 0.7900
# Epoch 156/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5554 - val_loss: 0.7895
# Epoch 157/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5555 - val_loss: 0.7899
# Epoch 158/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5552 - val_loss: 0.7889
# Epoch 159/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5555 - val_loss: 0.7891
# Epoch 160/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5551 - val_loss: 0.7883
# Epoch 161/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5552 - val_loss: 0.7885
# Epoch 162/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5551 - val_loss: 0.7888
# Epoch 163/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5553 - val_loss: 0.7889
# Epoch 164/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5548 - val_loss: 0.7889
# Epoch 165/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5549 - val_loss: 0.7915
# Epoch 166/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5550 - val_loss: 0.7897
# Epoch 167/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5548 - val_loss: 0.7888
# Epoch 168/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5548 - val_loss: 0.7879
# Epoch 169/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5546 - val_loss: 0.7891
# Epoch 170/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5546 - val_loss: 0.7880
# Epoch 171/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5545 - val_loss: 0.7907
# Epoch 172/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5545 - val_loss: 0.7885
# Epoch 173/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5544 - val_loss: 0.7879
# Epoch 174/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5545 - val_loss: 0.7937
# Epoch 175/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5546 - val_loss: 0.7899
# Epoch 176/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5543 - val_loss: 0.7885
# Epoch 177/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5542 - val_loss: 0.7887
# Epoch 178/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5546 - val_loss: 0.7904
# Epoch 179/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5541 - val_loss: 0.7897
# Epoch 180/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5541 - val_loss: 0.7884
# Epoch 181/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5541 - val_loss: 0.7876
# Epoch 182/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5542 - val_loss: 0.7884
# Epoch 183/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5540 - val_loss: 0.7899
# Epoch 184/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5540 - val_loss: 0.7904
# Epoch 185/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5539 - val_loss: 0.7879
# Epoch 186/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5538 - val_loss: 0.7905
# Epoch 187/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5539 - val_loss: 0.7877
# Epoch 188/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5540 - val_loss: 0.7889
# Epoch 189/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5536 - val_loss: 0.7870
# Epoch 190/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5534 - val_loss: 0.7875
# Epoch 191/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5539 - val_loss: 0.7869
# Epoch 192/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5533 - val_loss: 0.7874
# Epoch 193/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5535 - val_loss: 0.7868
# Epoch 194/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5532 - val_loss: 0.7865
# Epoch 195/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5534 - val_loss: 0.7870
# Epoch 196/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5529 - val_loss: 0.7867
# Epoch 197/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5528 - val_loss: 0.7893
# Epoch 198/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5528 - val_loss: 0.7860
# Epoch 199/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5525 - val_loss: 0.7864
# Epoch 200/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5525 - val_loss: 0.7871
# Epoch 201/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5522 - val_loss: 0.7859
# Epoch 202/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5525 - val_loss: 0.7865
# Epoch 203/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5522 - val_loss: 0.7881
# Epoch 204/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5523 - val_loss: 0.7869
# Epoch 205/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5521 - val_loss: 0.7864
# Epoch 206/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5521 - val_loss: 0.7861
# Epoch 207/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5521 - val_loss: 0.7864
# Epoch 208/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5522 - val_loss: 0.7870
# Epoch 209/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5525 - val_loss: 0.7870
# Epoch 210/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5520 - val_loss: 0.7876
# Epoch 211/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5522 - val_loss: 0.7864
# Epoch 212/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5521 - val_loss: 0.7886
# Epoch 213/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5522 - val_loss: 0.7884
# Epoch 214/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5520 - val_loss: 0.7886
# Epoch 215/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5521 - val_loss: 0.7887
# Epoch 216/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5520 - val_loss: 0.7888
# Epoch 217/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5521 - val_loss: 0.7887
# Epoch 218/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5520 - val_loss: 0.7890
# Epoch 219/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5520 - val_loss: 0.7886
# Epoch 220/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5517 - val_loss: 0.7880
# Epoch 221/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5517 - val_loss: 0.7880
# Epoch 222/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5517 - val_loss: 0.7882
# Epoch 223/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5516 - val_loss: 0.7884
# Epoch 224/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5518 - val_loss: 0.7882
# Epoch 225/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5517 - val_loss: 0.7878
# Epoch 226/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5517 - val_loss: 0.7887
# Epoch 227/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5515 - val_loss: 0.7889
# Epoch 228/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5515 - val_loss: 0.7886
# Epoch 229/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5516 - val_loss: 0.7893
# Epoch 230/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5515 - val_loss: 0.7890
# Epoch 231/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5515 - val_loss: 0.7890
# Epoch 232/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5517 - val_loss: 0.7880
# Epoch 233/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5513 - val_loss: 0.7885
# Epoch 234/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5514 - val_loss: 0.7877
# Epoch 235/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5514 - val_loss: 0.7877
# Epoch 236/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5512 - val_loss: 0.7877
# Epoch 237/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5516 - val_loss: 0.7879
# Epoch 238/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5513 - val_loss: 0.7873
# Epoch 239/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5514 - val_loss: 0.7894
# Epoch 240/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5512 - val_loss: 0.7877
# Epoch 241/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5514 - val_loss: 0.7872
# Epoch 242/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5514 - val_loss: 0.7875
# Epoch 243/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5513 - val_loss: 0.7865
# Epoch 244/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5511 - val_loss: 0.7884
# Epoch 245/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5517 - val_loss: 0.7873
# Epoch 246/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5511 - val_loss: 0.7858
# Epoch 247/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5512 - val_loss: 0.7861
# Epoch 248/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5512 - val_loss: 0.7897
# Epoch 249/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5512 - val_loss: 0.7875
# Epoch 250/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5511 - val_loss: 0.7875
# Epoch 251/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5513 - val_loss: 0.7882
# Epoch 252/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5512 - val_loss: 0.7870
# Epoch 253/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5513 - val_loss: 0.7868
# Epoch 254/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5511 - val_loss: 0.7859
# Epoch 255/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5509 - val_loss: 0.7888
# Epoch 256/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5512 - val_loss: 0.7879
# Epoch 257/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5512 - val_loss: 0.7885
# Epoch 258/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5515 - val_loss: 0.7875
# Epoch 259/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5514 - val_loss: 0.7874
# Epoch 260/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5513 - val_loss: 0.7872
# Epoch 261/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5516 - val_loss: 0.7890
# Epoch 262/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5511 - val_loss: 0.7892
# Epoch 263/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5512 - val_loss: 0.7877
# Epoch 264/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5512 - val_loss: 0.7882
# Epoch 265/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5512 - val_loss: 0.7877
# Epoch 266/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5509 - val_loss: 0.7876
# Epoch 267/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5509 - val_loss: 0.7871
# Epoch 268/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5510 - val_loss: 0.7873
# Epoch 269/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5510 - val_loss: 0.7858
# Epoch 270/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5512 - val_loss: 0.7857
# Epoch 271/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5510 - val_loss: 0.7871
# Epoch 272/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5511 - val_loss: 0.7859
# Epoch 273/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5510 - val_loss: 0.7861
# Epoch 274/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5511 - val_loss: 0.7858
# Epoch 275/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5509 - val_loss: 0.7850
# Epoch 276/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5509 - val_loss: 0.7851
# Epoch 277/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5509 - val_loss: 0.7866
# Epoch 278/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5508 - val_loss: 0.7863
# Epoch 279/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5508 - val_loss: 0.7881
# Epoch 280/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5509 - val_loss: 0.7861
# Epoch 281/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5510 - val_loss: 0.7857
# Epoch 282/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5510 - val_loss: 0.7873
# Epoch 283/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5509 - val_loss: 0.7873
# Epoch 284/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5508 - val_loss: 0.7877
# Epoch 285/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5508 - val_loss: 0.7879
# Epoch 286/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5510 - val_loss: 0.7880
# Epoch 287/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5508 - val_loss: 0.7877
# Epoch 288/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5508 - val_loss: 0.7870
# Epoch 289/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5508 - val_loss: 0.7865
# Epoch 290/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5508 - val_loss: 0.7873
# Epoch 291/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5507 - val_loss: 0.7874
# Epoch 292/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5509 - val_loss: 0.7887
# Epoch 293/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5510 - val_loss: 0.7875
# Epoch 294/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5507 - val_loss: 0.7879
# Epoch 295/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5510 - val_loss: 0.7875
# Epoch 296/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5508 - val_loss: 0.7884
# Epoch 297/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5507 - val_loss: 0.7872
# Epoch 298/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5508 - val_loss: 0.7872
# Epoch 299/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5506 - val_loss: 0.7875
# Epoch 300/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5509 - val_loss: 0.7880
# Epoch 301/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5507 - val_loss: 0.7878
# Epoch 302/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5510 - val_loss: 0.7886
# Epoch 303/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5505 - val_loss: 0.7875
# Epoch 304/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5510 - val_loss: 0.7892
# Epoch 305/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5506 - val_loss: 0.7875
# Epoch 306/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5507 - val_loss: 0.7901
# Epoch 307/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5506 - val_loss: 0.7874
# Epoch 308/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5511 - val_loss: 0.7870
# Epoch 309/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5506 - val_loss: 0.7877
# Epoch 310/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5508 - val_loss: 0.7881
# Epoch 311/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5506 - val_loss: 0.7871
# Epoch 312/500
# 2438/2438 [==============================] - 3s 1ms/step - loss: 0.5506 - val_loss: 0.7887
# Epoch 313/500
# 1772/2438 [====================>.........] - ETA: 0s - loss: 0.5343

# %%
# 평가하기
plt.figure()
plt.plot(range(nb_epochs), history['loss'])
plt.plot(range(nb_epochs), history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train Loss', 'Validation Loss'], loc='upper right');
plt.ylim([0, 1])
plt.show()

# %%
'''
오류 분포표
- 정밀도(Precision)
: 참인데 참이라고 예측한 데이터 / 참이라고 예측한 데이터
: 정상인데 정상이라고 예측한 데이터 / 정상이라고 예측한 데이터
- 재현율(Recall)
: 참인데 참이라고 예측한 데이터 / 실제로 참인 데이터
: 정상인테 정상이라고 예측한 데이터 / 실제로 정상인 데이터
'''
predictions = autoencoder.predict(X_test)
mse = np.mean(np.power((X_test - predictions), 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
# 539/539 [==============================] - 0s 602us/step
#        reconstruction_error  true_class
# count          17244.000000     17244.0
# mean               0.178130         0.0
# std                0.119982         0.0
# min                0.002070         0.0
# 25%                0.088286         0.0
# 50%                0.177009         0.0
# 75%                0.255443         0.0
# max                0.632334         0.0

# %%
# 정상 거래 데이터들의 재구성 오류 분포
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)
ax.set_title('normal reconstruction error distribution')
ax.set_xlabel('reconstruction error')
ax.set_ylabel('data')
# Out:
# Text(0, 0.5, 'data')

# %%
# 이상 거래 데이터들의 재구성 오류 분포
fig = plt.figure()
ax = fig.add_subplot(111)
Abnormal_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(Abnormal_error_df.reconstruction_error.values, bins=10)
ax.set_title('abnormal reconstruction error distribution')
ax.set_xlabel('reconstruction error')
ax.set_ylabel('data')
plt.show();

# %%
# ROC 곡선을 통한 평가
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)
# ROC 곡선은 이진 분류기(binary classifier)의 성능을 평가하는 유용한 도구이다.
# 굉정히 불균형한 데이터셋을 가지고 있기 때문에 일반적인 경우가 아님
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)
# Out:
# C:\Users\박범준\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_ranking.py:999: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(

# %%
predictions = autoencoder.predict(X_train)
square_error1 = np.power((X_train - predictions), 2)
mse= np.mean(square_error1, axis=1)
# thresholds = np.mean(mse, axis=0)
# thresholds = np.mean(mse,axis=0) + 1.68 * np.var(mse,axis=0)
aver_rmse = np.mean(np.sqrt(mse), axis=0)
thresholds = aver_rmse

plt.figure()
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show();

# Threshold vs precision
plt.plot(th, precision[1:], 'b', label='Threshold-Precision curve')
plt.title('Precision for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision')
plt.show();

# Threshold vs Recall
plt.plot(th, recall[1:], 'b', label='Threshold-Recall curve')
plt.title('Recall for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Recall')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\박범준\Desktop\Python\DAE_ver1.ipynb Cell 12 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/%EB%B0%95%EB%B2%94%EC%A4%80/Desktop/Python/DAE_ver1.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> predictions = autoencoder.predict(X_train2)
#       <a href='vscode-notebook-cell:/c%3A/Users/%EB%B0%95%EB%B2%94%EC%A4%80/Desktop/Python/DAE_ver1.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> square_error1 = np.power((X_train2 - predictions), 2)
#       <a href='vscode-notebook-cell:/c%3A/Users/%EB%B0%95%EB%B2%94%EC%A4%80/Desktop/Python/DAE_ver1.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> mse= np.mean(square_error1, axis=1)
#
# NameError: name 'X_train2' is not defined

# %%
#
predictions = autoencoder.predict(X_train)
square_error1 = np.power((X_train - predictions), 2)
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Abnormal" if name == 1 else "Normal")
ax.hlines(thresholds, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Abnormal" if name == 1 else "Normal")
ax.hlines(thresholds, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.ylim([0, 10])
plt.show();

y_pred = [1 if e > thresholds else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
# Out:
# 610/610 [==============================] - 0s 704us/step
