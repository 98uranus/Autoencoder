# %%
from sklearn.mixture import GaussianMixture
from sklearn.metrics import precision_score, recall_score, f1_score, auc
from sklearn.model_selection import train_test_split
from keras import layers, Model
from keras.models import Sequential, load_model
import numpy as np
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping
from keras import regularizers, layers, losses
from keras.callbacks import ModelCheckpoint, TensorBoard
from sklearn.metrics import precision_recall_curve, confusion_matrix, roc_curve, PrecisionRecallDisplay
from keras.utils import plot_model
import pandas as pd
import seaborn as sns
import joblib

# %%
# Generate some sample data for the autoencoder
# x_train = np.random.rand(1000, 12)
# x_test = np.random.rand(100, 12)

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

RANDOM_SEED = 42

df = pd.read_csv("Autoencoder1.csv")
print(df.shape)

LABELS = ["Normal", "Abnormal"]

count_classes =pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Data Class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Data")
plt.show();

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from cmath import pi

data = df.drop(['Time'], axis=1)
y_true = df['Class']

r2d = 180/pi

data['P'] = r2d * data['P']
data['Q'] = r2d * data['Q']
data['R'] = r2d * data['R']
data['Phi'] = r2d * data['Phi']
data['Theta'] = r2d * data['Theta']
data['Psi'] = r2d * data['Psi']
# Out:
# (39000, 14)

# %%
X_train, X_test = train_test_split(data, test_size=0.5, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
y_train = X_train['Class']
X_train = pd.DataFrame(X_train)
X_train = X_train.drop(['Class'], axis=1)

# X_test = X_test[X_test.Class == 0]
y_test = X_test['Class']
X_test = pd.DataFrame(X_test)
X_test = X_test.drop(['Class'], axis=1)

def MinmaxNorm(data1, data2, label):
    for i in label:
        a = data1[i]
        b = data2[i]
        x_max = max(a)
        x_min = min(a)
        for j in list(range(a.shape[0])):
            a.iloc[j] = (a.iloc[j] - x_min) / (x_max - x_min)
        for k in list(range(b.shape[0])):
            b.iloc[k] = (b.iloc[k] - x_min) / (x_max - x_min)
    
    return data1, data2

A = ['RPM1', 'RPM2', 'RPM3', 'RPM4', 'RPM5', 'RPM6', 'P', 'Q', 'R', 'Phi', 'Theta', 'Psi']

X_train, X_test = MinmaxNorm(X_train, X_test, A)

# Add noise 
noise = 0.5
X_train_noisy = X_train + noise * np.random.normal(loc=0.0, scale=1.0, size=X_train.shape)
X_test_noisy = X_test + noise * np.random.normal(loc=0.0, scale=1.0, size=X_test.shape)

X_train = X_train.values
X_test = X_test.values

# %%
input_dim = 12
latent_dim = 4

class Autoencoder(Model):
    def __init__(self, latent_dim):
        super(Autoencoder, self).__init__()
        self.latent_dim = latent_dim
        self.encoder = Sequential([
            # layers.Dense(8, activation='sigmoid',
            #             activity_regularizer=regularizers.l2(10e-3)),
            layers.Dense(latent_dim, activation='relu'),
        ])
        self.decoder = Sequential([
            layers.Dense(input_dim, activation='relu'),
        ])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
autoencoder = Autoencoder(latent_dim)
autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())
callback = EarlyStopping(monitor='val_loss', patience=3)
checkpointer = ModelCheckpoint(filepath="DAGMM_AE2_origin_l4",
                               monitor='val_loss',
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

batch_size = 12
nb_epochs = 100
history = autoencoder.fit(X_train_noisy, X_train,
                        epochs=nb_epochs,
                        batch_size=batch_size,
                        shuffle=True,
                        validation_split=0.4,
                        callbacks=[checkpointer, tensorboard]).history

autoencoder.summary()
# Out:
# Epoch 1/100
# 817/864 [===========================>..] - ETA: 0s - loss: 0.1441INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 3s 2ms/step - loss: 0.1418 - val_loss: 0.1005
# Epoch 2/100
# 804/864 [==========================>...] - ETA: 0s - loss: 0.0973INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0971 - val_loss: 0.0954
# Epoch 3/100
# 846/864 [============================>.] - ETA: 0s - loss: 0.0948INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0948 - val_loss: 0.0946
# Epoch 4/100
# 844/864 [============================>.] - ETA: 0s - loss: 0.0942INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0943 - val_loss: 0.0940
# Epoch 5/100
# 840/864 [============================>.] - ETA: 0s - loss: 0.0937INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0936 - val_loss: 0.0932
# Epoch 6/100
# 832/864 [===========================>..] - ETA: 0s - loss: 0.0930INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0931 - val_loss: 0.0930
# Epoch 7/100
# 825/864 [===========================>..] - ETA: 0s - loss: 0.0930INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0929 - val_loss: 0.0930
# Epoch 8/100
# 849/864 [============================>.] - ETA: 0s - loss: 0.0927INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0928 - val_loss: 0.0928
# Epoch 9/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0928 - val_loss: 0.0929
# Epoch 10/100
# 811/864 [===========================>..] - ETA: 0s - loss: 0.0927INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0927 - val_loss: 0.0927
# Epoch 11/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0927 - val_loss: 0.0928
# Epoch 12/100
# 846/864 [============================>.] - ETA: 0s - loss: 0.0926INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0927 - val_loss: 0.0927
# Epoch 13/100
# 822/864 [===========================>..] - ETA: 0s - loss: 0.0927INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0927 - val_loss: 0.0927
# Epoch 14/100
# 847/864 [============================>.] - ETA: 0s - loss: 0.0926INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0927 - val_loss: 0.0927
# Epoch 15/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0926 - val_loss: 0.0927
# Epoch 16/100
# 847/864 [============================>.] - ETA: 0s - loss: 0.0926INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0926 - val_loss: 0.0926
# Epoch 17/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0926 - val_loss: 0.0926
# Epoch 18/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0926 - val_loss: 0.0927
# Epoch 19/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0926 - val_loss: 0.0927
# Epoch 20/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0926 - val_loss: 0.0927
# Epoch 21/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0925 - val_loss: 0.0927
# Epoch 22/100
# 863/864 [============================>.] - ETA: 0s - loss: 0.0925INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0925 - val_loss: 0.0926
# Epoch 23/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0925 - val_loss: 0.0926
# Epoch 24/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0925 - val_loss: 0.0927
# Epoch 25/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0925 - val_loss: 0.0926
# Epoch 26/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0925 - val_loss: 0.0929
# Epoch 27/100
# 815/864 [===========================>..] - ETA: 0s - loss: 0.0924INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0925 - val_loss: 0.0926
# Epoch 28/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0925 - val_loss: 0.0926
# Epoch 29/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 30/100
# 858/864 [============================>.] - ETA: 0s - loss: 0.0924INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 31/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 32/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 33/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 34/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 35/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0927
# Epoch 36/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 37/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 38/100
# 853/864 [============================>.] - ETA: 0s - loss: 0.0924INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 39/100
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 40/100
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0924 - val_loss: 0.0927
# Epoch 41/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 42/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 43/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 44/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 45/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 46/100
# 841/864 [============================>.] - ETA: 0s - loss: 0.0924INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 47/100
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 48/100
# 862/864 [============================>.] - ETA: 0s - loss: 0.0924INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 49/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 50/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0924 - val_loss: 0.0927
# Epoch 51/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 52/100
# 824/864 [===========================>..] - ETA: 0s - loss: 0.0925INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 53/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 54/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 55/100
# 833/864 [===========================>..] - ETA: 0s - loss: 0.0925INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 56/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 57/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 58/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 59/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 60/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 61/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 62/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 63/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 64/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 65/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 66/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 67/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 68/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0927
# Epoch 69/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 70/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 71/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 72/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 73/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 74/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 75/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 76/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 77/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 78/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 79/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 80/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 81/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 82/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 83/100
# 811/864 [===========================>..] - ETA: 0s - loss: 0.0924INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 84/100
# 862/864 [============================>.] - ETA: 0s - loss: 0.0924INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 85/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 86/100
# 864/864 [==============================] - 1s 2ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 87/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 88/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 89/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 90/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 91/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 92/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 93/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 94/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 95/100
# 840/864 [============================>.] - ETA: 0s - loss: 0.0924INFO:tensorflow:Assets written to: DAGMM_AE2_origin_l4\assets
# 864/864 [==============================] - 2s 2ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 96/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0926
# Epoch 97/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 98/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Epoch 99/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0927
# Epoch 100/100
# 864/864 [==============================] - 1s 1ms/step - loss: 0.0924 - val_loss: 0.0925
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 4)                 52
#
#  sequential_1 (Sequential)   (None, 12)                60
#
# =================================================================
# Total params: 112
# Trainable params: 112
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.plot(range(nb_epochs), history['loss'], label='Training Loss')
plt.plot(range(nb_epochs), history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Use the trained autoencoder to encode the training data
encoded_data = autoencoder.encoder(X_train).numpy()

# Fit a Gaussian Mixture Model with 2 components to the encoded training data
gmm = GaussianMixture(n_components=1)
gmm.fit(encoded_data)
saved_gmm = joblib.dump(gmm, 'DAGMM_GMM2_origin_l4_n1.pkl')

# %%
# Use the GMM to predict the probability densities for the encoded test data
encoded_test_data = autoencoder.encoder(X_test).numpy()
scores = gmm.score_samples(encoded_test_data) # score_samples: PDF of the test data

# Identify anomalies based on the GMM probability densities
threshold = np.percentile(scores, 10.6)
anomalies = X_test[scores < threshold]
# print("scores :", scores)
# print("threshold :", threshold)
# print("anomalies :", anomalies)
# print("scores < threshold :", scores < threshold)

# Calculate precision, recall, and F1 score
y_pred = np.zeros_like(scores)
y_pred[scores < threshold] = 1
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, F1 score: {f1:.4f}")
# Out:
# Precision: 0.9961, Recall: 0.9127, F1 score: 0.9526

# %%
# Calculate precision, recall, and F1 score
y_pred = np.zeros_like(scores)
y_pred[scores < threshold] = 1
precision, recall, thresholds1 = precision_recall_curve(y_test, y_pred)
fpr, tpr, thresholds2 = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
f1 = f1_score(y_test, y_pred)
# PrecisionRecallDisplay.from_predictions(y_test, y_pred)
# plt.plot(ax=None,name=None)
# plt.xlim([-0.01, 1.0])
# plt.ylim([0.0, 1.001])

# ROC curve
plt.figure()
plt.plot(fpr, tpr, 'b', label='AUC= %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0, 1], [0, 1], 'r--')
# plt.xlim([-0.001, 1.0])
# plt.ylim([0.0, 1.001])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show();

# precision recall curve
plt.figure()
plt.plot(recall, precision, 'b', label='F1 score = %0.4f'% f1)
plt.title('Recall vs Precision')
# plt.xlim([-0.001, 1.0])
# plt.ylim([0.0, 1.001])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(loc='lower left')
plt.show();

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
LABELS = ["Normal", "Abnormal"]
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, 
                        annot=True, fmt="d", annot_kws={'size': 20}, cmap="YlGnBu", 
                        vmin=0, vmax=4000);
plt.title("Confusion matrix")
plt.xlabel('Predicted class')
plt.ylabel('True class')
plt.show()
